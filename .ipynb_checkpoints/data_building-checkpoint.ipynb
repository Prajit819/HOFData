# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float 
import pymysql
engine = create_engine('mysql+pymysql://root:Sp@ceBall5@localhost:3306/lahman2016')
connection = engine.connect()
# Out:
# /Users/kristopherking/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)

# %%
# SELECTING ALL PLAYERS NOMINATED OR INDUCTED IN THE MLB HALL OF FAME
hallOF = pd.read_sql("SELECT * from `HallOfFame` WHERE Category='Player' and votedBy='BBWAA'", connection)
# CREATING A LIST OF THE HOF PLAYER IDs
hallOF_players = hallOF['playerID'].unique()
print("Number of HOF Players: " + str(len(hallOF_players)))
# Out:
# Number of HOF Players: 1130

# %%
# CREATE PICTHER ID LIST FROM ALL PITCHERS IN MLB
pitcher_id = pd.read_sql("SELECT Pos, playerID from `Fielding` where Pos='P'", connection)
pitcher_id_list = pitcher_id['playerID'].unique()
print("Number of MLB Pitchers: " + str(len(pitcher_id_list)))
# Out:
# Number of MLB Pitchers: 9302

# %%
# STORING HOF FIELDERS AND PITCHERS PLAYER IDs IN SEPERATE LISTS
fielders_HOF = []   # Excludes pitchers

pitchers_HOF = []  # Store pitchers

for h in hallOF_players:
    if h not in pitcher_id_list:
        if h not in fielders_HOF:
            fielders_HOF.append(h)
    else:
        if h not in pitchers_HOF:
            pitchers_HOF.append(h)
print("Number of HOF Fielders: " + str(len(fielders_HOF)))            
print("Number of HOF Pitchers: " + str(len(pitchers_HOF)))
# Out:
# Number of HOF Fielders: 681
# Number of HOF Pitchers: 449

# %%
# COLLECT ALL UNIQUE PLAYER IDs FROM BATTING TABLE
batters = pd.read_sql("SELECT playerID from `Batting`", connection)
batter_list = batters['playerID'].unique().tolist()
print("Number of Batters (including pitchers): " + str(len(batter_list)))
# REMOVE PLAYER IDs THAT ARE IDENTIFIED AS BEING PITCHERS
for b in batter_list:
    if b in pitcher_id_list:
        batter_list.remove(b)
print("Number of Batters (without pitchers): " + str(len(batter_list)))
# Out:
# Number of Batters (including pitchers): 18915
# Number of Batters (without pitchers): 12716

# %%
# STORE ALL PITCHERS (NON-HOF) THAT HAVE 10 OR MORE SEASONS IN TO A LIST BY PLAYER ID
pitchers_NonHOF = []
for p in pitcher_id_list:
    if p not in pitchers_HOF:
        pitchers_NonHOF.append(p)
print("Number of Non-HOF Pitchers: " + str(len(pitchers_NonHOF)))
# Out:
# Number of Non-HOF Pitchers: 8853

# %%
# CREATE DF FROM ALL PITCHERS
pitchers = pd.read_sql("SELECT * from `Pitching` where playerID in %s" % str(tuple(pitcher_id_list)), connection)
pitch = pd.DataFrame(pitchers)
# REPLACE BLANK VALUES
pitch.replace('', 0, inplace=True)
pitch.replace(0, 0.01, inplace=True)
pitch.head()
print(pitch.shape)
# Out:
# (44963, 30)

# %%
pitching_df = pd.DataFrame()
x = 0
#LOOP THROUGH THE PITCHERS LIST
for p in pitcher_id_list[:-1]:
    a = pd.read_sql("SELECT * from `Pitching` where playerID='%s'" % p, connection)
    # SELECT PITCHERS
    if len(a) >= 0:
        seasons_count = len(a)
        print('Running data on %s: record %s of %s' %(p, x, len(pitcher_id_list)-1))
        name_pull = pd.read_sql("SELECT nameLast, NameGiven from `Master` where playerID = '%s'"% p, connection)
        lastName = name_pull['nameLast'][0]
        firstName = name_pull['NameGiven'][0]
        pit = pitch[(pitch.playerID==p)]
        pit[['W','L','G','GS','CG','SHO','SV','IPouts','H','ER','HR','BB','SO','BAOpp','ERA','IBB','WP','HBP',
      'BK','BFP','GF','R','SH','SF','GIDP']].astype(str).astype(float)
        z = pit['playerID'].count()
        win = pit['W'].sum()
        loss = pit['L'].sum()
        games = pit['G'].sum()
        games_started = pit['GS'].sum()
        complete = pit['CG'].sum()
        shutout = pit['SHO'].sum()
        save = pit['SV'].sum()
        ipOut = pit['IPouts'].sum()
        print(len(pit))
        era = pit['ERA'].sum()/len(pit)
        runs = pit['ER'].sum()
        hits = pit['H'].sum()
        hr = pit['HR'].sum()
        OppBA = pit['BAOpp'].astype(str).astype(float).sum()/z
        strikes = pit['SO'].sum()
        walks = pit['BB'].sum()
        if p in pitchers_HOF:
            hof = 'Y'
        else:
            hof = 'N'
        #APPEND STATS TO A DF
        pitching_df = pitching_df.append({
            'player_id': p,
            'firstName': firstName,
            'lastName': lastName, 
            'games': games,
            'wins': win,
            'losses': loss,
            'started': games_started,
            'completed': complete,
            'shutouts': shutout,
            'saves': save,
            'outs_pitched': ipOut,
            'ERA': era,
            'runs_earned': runs,
            'hits': hits,
            'homeruns': hr,
            'Opposing_BA': OppBA,
            'strikes': strikes,
            'walks': walks,
            'HOF': hof,
            'seasons': seasons_count
        }, ignore_index = True)
        x+=1
    else:
        print('Record for %s skipped' % p)
        next
# Out:
# Running data on bechtge01: record 0 of 9301
# 5
# Running data on brainas01: record 1 of 9301
# 5
# Running data on fergubo01: record 2 of 9301
# 6
# Running data on fishech01: record 3 of 9301
# 7
# Running data on fleetfr01: record 4 of 9301
# 4
# Running data on flowedi01: record 5 of 9301
# 1
# Running data on mackde01: record 6 of 9301
# 1
# Running data on mathebo01: record 7 of 9301
# 16
# Running data on mcbridi01: record 8 of 9301
# 6
# Running data on mcmuljo01: record 9 of 9301
# 4
# Running data on meyerle01: record 10 of 9301
# 2
# Running data on paborch01: record 11 of 9301
# 3
# Running data on pinkhed01: record 12 of 9301
# 1
# Running data on prattal01: record 13 of 9301
# 2
# Running data on spaldal01: record 14 of 9301
# 7
# Running data on stearbi01: record 15 of 9301
# 5
# Running data on woltery01: record 16 of 9301
# 3
# Running data on wrighha01: record 17 of 9301
# 4
# Running data on zettlge01: record 18 of 9301
# 8
# Running data on bentlcy01: record 19 of 9301
# 1
# Running data on brittji01: record 20 of 9301
# 2
# Running data on buttefr01: record 21 of 9301
# 1
# Running data on cummica01: record 22 of 9301
# 6
# Running data on malonma01: record 23 of 9301
# 1
# Running data on martiph01: record 24 of 9301
# 3
# Running data on mcderjo01: record 25 of 9301
# 1
# Running data on orour01: record 26 of 9301
# 1
# Running data on campbhu01: record 27 of 9301
# 1
# Running data on forceda01: record 28 of 9301
# 2
# Running data on frencbi01: record 29 of 9301
# 1
# Running data on fulmech01: record 30 of 9301
# 1
# Running data on greasjo01: record 31 of 9301
# 1
# Running data on lovetle01: record 32 of 9301
# 1
# Running data on mcdoo01: record 33 of 9301
# 1
# Running data on selmafr01: record 34 of 9301
# 1
# Running data on strated01: record 35 of 9301
# 1
# Running data on bondto01: record 36 of 9301
# 11
# Running data on collida01: record 37 of 9301
# 1
# Running data on hatfijo01: record 38 of 9301
# 1
# Running data on mannija01: record 39 of 9301
# 5
# Running data on ryanjo01: record 40 of 9301
# 3
# Running data on arundha01: record 41 of 9301
# 3
# Running data on blongjo01: record 42 of 9301
# 3
# Running data on bordejo01: record 43 of 9301
# 2
# Running data on boydbi01: record 44 of 9301
# 1
# Running data on bradlge01: record 45 of 9301
# 9
# Running data on cassijo01: record 46 of 9301
# 2
# Running data on clintji01: record 47 of 9301
# 2
# Running data on devliji01: record 48 of 9301
# 3
# Running data on edwar01: record 49 of 9301
# 1
# Running data on galvipu01: record 50 of 9301
# 17
# Running data on gedneco01: record 51 of 9301
# 1
# Running data on goldemi01: record 52 of 9301
# 3
# Running data on heifefr01: record 53 of 9301
# 1
# Running data on knighge01: record 54 of 9301
# 1
# Running data on knighlo01: record 55 of 9301
# 5
# Running data on luffhe01: record 56 of 9301
# 1
# Running data on masonch01: record 57 of 9301
# 1
# Running data on mcveyca01: record 58 of 9301
# 4
# Running data on morgapi01: record 59 of 9301
# 1
# Running data on nichotr01: record 60 of 9301
# 6
# Running data on oneilj01: record 61 of 9301
# 1
# Running data on parksbi01: record 62 of 9301
# 2
# Running data on pearcdi01: record 63 of 9301
# 1
# Running data on suttoez01: record 64 of 9301
# 1
# Running data on weavesa01: record 65 of 9301
# 6
# Running data on withech01: record 66 of 9301
# 1
# Running data on wrighge01: record 67 of 9301
# 2
# Running data on barnero01: record 68 of 9301
# 1
# Running data on bootham01: record 69 of 9301
# 2
# Running data on boothed01: record 70 of 9301
# 1
# Running data on bradlfo01: record 71 of 9301
# 1
# Running data on clackbo01: record 72 of 9301
# 1
# Running data on coonwi01: record 73 of 9301
# 1
# Running data on deando01: record 74 of 9301
# 1
# Running data on gouldch01: record 75 of 9301
# 1
# Running data on laffefl01: record 76 of 9301
# 1
# Running data on larkite01: record 77 of 9301
# 5
# Running data on pearcfr01: record 78 of 9301
# 1
# Running data on peterjo01: record 79 of 9301
# 1
# Running data on piersda01: record 80 of 9301
# 1
# Running data on whitede01: record 81 of 9301
# 2
# Running data on willida01: record 82 of 9301
# 1
# Running data on battijo01: record 83 of 9301
# 2
# Running data on mitchbo01: record 84 of 9301
# 4
# Running data on reisla01: record 85 of 9301
# 2
# Running data on roweda01: record 86 of 9301
# 4
# Running data on whitewi01: record 87 of 9301
# 10
# Running data on allisdo01: record 88 of 9301
# 1
# Running data on brownle01: record 89 of 9301
# 2
# Running data on coreyfr01: record 90 of 9301
# 6
# Running data on ellicjo01: record 91 of 9301
# 1
# Running data on hankifr01: record 92 of 9301
# 4
# Running data on healeto01: record 93 of 9301
# 2
# Running data on mccorji01: record 94 of 9301
# 12
# Running data on mckelru01: record 95 of 9301
# 1
# Running data on nolanth01: record 96 of 9301
# 5
# Running data on wardjo01: record 97 of 9301
# 7
# Running data on wheelha01: record 98 of 9301
# 5
# Running data on broutda01: record 99 of 9301
# 2
# Running data on dorgami01: record 100 of 9301
# 4
# Running data on foleycu01: record 101 of 9301
# 5
# Running data on gardngi01: record 102 of 9301
# 5
# Running data on goldsfr01: record 103 of 9301
# 7
# Running data on mccorha01: record 104 of 9301
# 4
# Running data on mcgunbi01: record 105 of 9301
# 2
# Running data on mcmanpa01: record 106 of 9301
# 1
# Running data on neaglja01: record 107 of 9301
# 5
# Running data on purcebl01: record 108 of 9301
# 10
# Running data on richmle01: record 109 of 9301
# 6
# Running data on salisha01: record 110 of 9301
# 2
# Running data on tyngji01: record 111 of 9301
# 2
# Running data on burnsto01: record 112 of 9301
# 1
# Running data on corcola01: record 113 of 9301
# 9
# Running data on driscde01: record 114 of 9301
# 4
# Running data on evansja01: record 115 of 9301
# 3
# Running data on guthch01: record 116 of 9301
# 1
# Running data on hornujo01: record 117 of 9301
# 1
# Running data on keefeti01: record 118 of 9301
# 15
# Running data on kellyki01: record 119 of 9301
# 7
# Running data on learyja01: record 120 of 9301
# 6
# Running data on morrijo01: record 121 of 9301
# 7
# Running data on mountfr01: record 122 of 9301
# 9
# Running data on poormto01: record 123 of 9301
# 4
# Running data on stoveha01: record 124 of 9301
# 3
# Running data on welchmi01: record 125 of 9301
# 13
# Running data on wiedmst01: record 126 of 9301
# 11
# Running data on derbyge01: record 127 of 9301
# 3
# Running data on foxjo01: record 128 of 9301
# 4
# Running data on lynchja01: record 129 of 9301
# 7
# Running data on mullato01: record 130 of 9301
# 15
# Running data on radboch01: record 131 of 9301
# 11
# Running data on taylobi01: record 132 of 9301
# 9
# Running data on whitnji01: record 133 of 9301
# 10
# Running data on willine01: record 134 of 9301
# 7
# Running data on bohnch01: record 135 of 9301
# 1
# Running data on browned01: record 136 of 9301
# 2
# Running data on brownto01: record 137 of 9301
# 5
# Running data on buffich01: record 138 of 9301
# 11
# Running data on burkeja01: record 139 of 9301
# 3
# Running data on clarkjo01: record 140 of 9301
# 13
# Running data on comisch01: record 141 of 9301
# 3
# Running data on critcmo01: record 142 of 9301
# 2
# Running data on dailyhu01: record 143 of 9301
# 7
# Running data on dorrbe01: record 144 of 9301
# 1
# Running data on doylejo02: record 145 of 9301
# 1
# Running data on eganji01: record 146 of 9301
# 1
# Running data on ewingbu01: record 147 of 9301
# 6
# Running data on fusseed01: record 148 of 9301
# 1
# Running data on geisbi01: record 149 of 9301
# 2
# Running data on halbred01: record 150 of 9301
# 1
# Running data on heckegu01: record 151 of 9301
# 9
# Running data on hoganed01: record 152 of 9301
# 1
# Running data on landido01: record 153 of 9301
# 2
# Running data on mcginju01: record 154 of 9301
# 7
# Running data on myershe01: record 155 of 9301
# 1
# Running data on reccijo01: record 156 of 9301
# 2
# Running data on reynoch01: record 157 of 9301
# 1
# Running data on robinya01: record 158 of 9301
# 4
# Running data on russjo01: record 159 of 9301
# 1
# Running data on schapjo01: record 160 of 9301
# 1
# Running data on schenbi01: record 161 of 9301
# 1
# Running data on seymoja01: record 162 of 9301
# 1
# Running data on snydege01: record 163 of 9301
# 1
# Running data on striccu01: record 164 of 9301
# 4
# Running data on sweenbi01: record 165 of 9301
# 2
# Running data on whitnar01: record 166 of 9301
# 3
# Running data on wisebi01: record 167 of 9301
# 3
# Running data on wolfji01: record 168 of 9301
# 3
# Running data on allenmy01: record 169 of 9301
# 3
# Running data on ansonca01: record 170 of 9301
# 2
# Running data on bakelje01: record 171 of 9301
# 9
# Running data on bakerno01: record 172 of 9301
# 3
# Running data on barrbo01: record 173 of 9301
# 6
# Running data on breital01: record 174 of 9301
# 1
# Running data on burnsdi01: record 175 of 9301
# 3
# Running data on cadych01: record 176 of 9301
# 2
# Running data on colemjo01: record 177 of 9301
# 7
# Running data on cushmed01: record 178 of 9301
# 7
# Running data on deaglre01: record 179 of 9301
# 3
# Running data on devinji01: record 180 of 9301
# 1
# Running data on dolanto01: record 181 of 9301
# 1
# Running data on dundoed01: record 182 of 9301
# 2
# Running data on emslibo01: record 183 of 9301
# 4
# Running data on friespe01: record 184 of 9301
# 1
# Running data on gallabi01: record 185 of 9301
# 2
# Running data on haganar01: record 186 of 9301
# 3
# Running data on hendeha01: record 187 of 9301
# 8
# Running data on hilsech01: record 188 of 9301
# 2
# Running data on hodnech01: record 189 of 9301
# 2
# Running data on huntele01: record 190 of 9301
# 1
# Running data on jonesja02: record 191 of 9301
# 2
# Running data on lilliji01: record 192 of 9301
# 3
# Running data on manseto01: record 193 of 9301
# 1
# Running data on mcintfr01: record 194 of 9301
# 2
# Running data on mclaufr01: record 195 of 9301
# 2
# Running data on mountbi01: record 196 of 9301
# 4
# Running data on oneilti01: record 197 of 9301
# 2
# Running data on orourji01: record 198 of 9301
# 2
# Running data on radboge01: record 199 of 9301
# 1
# Running data on sawyewi01: record 200 of 9301
# 1
# Running data on shawdu01: record 201 of 9301
# 7
# Running data on smithed01: record 202 of 9301
# 4
# Running data on smithpo01: record 203 of 9301
# 1
# Running data on sommejo01: record 204 of 9301
# 5
# Running data on sweench01: record 205 of 9301
# 6
# Running data on valenjo01: record 206 of 9301
# 1
# Running data on woodge01: record 207 of 9301
# 4
# Running data on andrufr01: record 208 of 9301
# 1
# Running data on atkinal01: record 209 of 9301
# 5
# Running data on aydelja01: record 210 of 9301
# 2
# Running data on baldwla01: record 211 of 9301
# 7
# Running data on bastich01: record 212 of 9301
# 1
# Running data on baueral01: record 213 of 9301
# 2
# Running data on becanbu01: record 214 of 9301
# 2
# Running data on beckfr01: record 215 of 9301
# 2
# Running data on begleed01: record 216 of 9301
# 2
# Running data on blackbo01: record 217 of 9301
# 1
# Running data on blaisdi01: record 218 of 9301
# 1
# Running data on boylehe01: record 219 of 9301
# 6
# Running data on brillfr01: record 220 of 9301
# 1
# Running data on brownji01: record 221 of 9301
# 4
# Running data on brownjo01: record 222 of 9301
# 2
# Running data on brownpe01: record 223 of 9301
# 1
# Running data on burnsoy01: record 224 of 9301
# 4
# Running data on cahiljo01: record 225 of 9301
# 3
# Running data on carutbo01: record 226 of 9301
# 9
# Running data on caseyda01: record 227 of 9301
# 7
# Running data on cattajo01: record 228 of 9301
# 2
# Running data on chattji01: record 229 of 9301
# 1
# Running data on conleed01: record 230 of 9301
# 1
# Running data on connojo01: record 231 of 9301
# 2
# Running data on connojo02: record 232 of 9301
# 3
# Running data on conwaji01: record 233 of 9301
# 3
# Running data on corcoja01: record 234 of 9301
# 1
# Running data on corcomi01: record 235 of 9301
# 1
# Running data on corkhpo01: record 236 of 9301
# 5
# Running data on coughed01: record 237 of 9301
# 1
# Running data on craneed01: record 238 of 9301
# 10
# Running data on crosbge01: record 239 of 9301
# 1
# Running data on crothdo01: record 240 of 9301
# 2
# Running data on cudwoji01: record 241 of 9301
# 1
# Running data on currywe01: record 242 of 9301
# 1
# Running data on daniech01: record 243 of 9301
# 1
# Running data on davisda01: record 244 of 9301
# 3
# Running data on dorseje01: record 245 of 9301
# 1
# Running data on drewda01: record 246 of 9301
# 1
# Running data on duganed01: record 247 of 9301
# 1
# Running data on dunlafr01: record 248 of 9301
# 2
# Running data on edench01: record 249 of 9301
# 2
# Running data on elybo01: record 250 of 9301
# 4
# Running data on ferguch01: record 251 of 9301
# 4
# Running data on firthte01: record 252 of 9301
# 1
# Running data on fishe01: record 253 of 9301
# 2
# Running data on fogarji01: record 254 of 9301
# 4
# Running data on foremfr01: record 255 of 9301
# 14
# Running data on foutzda01: record 256 of 9301
# 11
# Running data on gagusch01: record 257 of 9301
# 1
# Running data on galvilo01: record 258 of 9301
# 1
# Running data on geerbi01: record 259 of 9301
# 1
# Running data on getzich01: record 260 of 9301
# 10
# Running data on glassja01: record 261 of 9301
# 4
# Running data on gormaja01: record 262 of 9301
# 1
# Running data on hamiljo01: record 263 of 9301
# 1
# Running data on harkijo01: record 264 of 9301
# 5
# Running data on henryjo01: record 265 of 9301
# 3
# Running data on hibbajo01: record 266 of 9301
# 1
# Running data on hickmer01: record 267 of 9301
# 1
# Running data on hinespa01: record 268 of 9301
# 1
# Running data on horanjo01: record 269 of 9301
# 1
# Running data on housech01: record 270 of 9301
# 1
# Running data on hutchbi01: record 271 of 9301
# 9
# Running data on irwinar01: record 272 of 9301
# 2
# Running data on keenaji01: record 273 of 9301
# 3
# Running data on kented01: record 274 of 9301
# 1
# Running data on kimbesa01: record 275 of 9301
# 2
# Running data on kirbyjo01: record 276 of 9301
# 6
# Running data on knighjo01: record 277 of 9301
# 1
# Running data on kreegfr01: record 278 of 9301
# 1
# Running data on lauerch01: record 279 of 9301
# 1
# Running data on leeto01: record 280 of 9301
# 2
# Running data on lockwmi01: record 281 of 9301
# 1
# Running data on lynchto02: record 282 of 9301
# 1
# Running data on macarma01: record 283 of 9301
# 1
# Running data on mattecv01: record 284 of 9301
# 1
# Running data on maulal01: record 285 of 9301
# 16
# Running data on mccarto01: record 286 of 9301
# 6
# Running data on mccaual01: record 287 of 9301
# 1
# Running data on mccorje01: record 288 of 9301
# 1
# Running data on mcelrji01: record 289 of 9301
# 2
# Running data on mcfarch01: record 290 of 9301
# 1
# Running data on mckeola01: record 291 of 9301
# 4
# Running data on mclauba01: record 292 of 9301
# 1
# Running data on mclauji01: record 293 of 9301
# 1
# Running data on mcsortr01: record 294 of 9301
# 1
# Running data on meegape01: record 295 of 9301
# 2
# Running data on meinkfr01: record 296 of 9301
# 2
# Running data on millecy01: record 297 of 9301
# 4
# Running data on moffesa01: record 298 of 9301
# 3
# Running data on moriage01: record 299 of 9301
# 2
# Running data on morrie01: record 300 of 9301
# 1
# Running data on morried01: record 301 of 9301
# 7
# Running data on mortoch01: record 302 of 9301
# 1
# Running data on mortosp01: record 303 of 9301
# 1
# Running data on murphco01: record 304 of 9301
# 2
# Running data on murphjo01: record 305 of 9301
# 2
# Running data on nelsobi01: record 306 of 9301
# 1
# Running data on oberbhe01: record 307 of 9301
# 2
# Running data on obriebi01: record 308 of 9301
# 1
# Running data on odayha01: record 309 of 9301
# 8
# Running data on pfefffr01: record 310 of 9301
# 4
# Running data on portehe01: record 311 of 9301
# 6
# Running data on powelab01: record 312 of 9301
# 3
# Running data on pylesh01: record 313 of 9301
# 2
# Running data on radfopa01: record 314 of 9301
# 6
# Running data on recciph01: record 315 of 9301
# 4
# Running data on ryanjo02: record 316 of 9301
# 1
# Running data on seradbi01: record 317 of 9301
# 4
# Running data on shallgu01: record 318 of 9301
# 2
# Running data on smith01: record 319 of 9301
# 1
# Running data on smithed05: record 320 of 9301
# 1
# Running data on smithge01: record 321 of 9301
# 1
# Running data on smithph01: record 322 of 9301
# 12
# Running data on sullifl01: record 323 of 9301
# 1
# Running data on sullipa01: record 324 of 9301
# 1
# Running data on sullisl01: record 325 of 9301
# 1
# Running data on sullito01: record 326 of 9301
# 4
# Running data on swarted01: record 327 of 9301
# 2
# Running data on sylvelo01: record 328 of 9301
# 1
# Running data on tennefr01: record 329 of 9301
# 2
# Running data on terryad01: record 330 of 9301
# 16
# Running data on thompar01: record 331 of 9301
# 1
# Running data on trumbed01: record 332 of 9301
# 1
# Running data on veachpe01: record 333 of 9301
# 2
# Running data on vintobi01: record 334 of 9301
# 3
# Running data on vossal01: record 335 of 9301
# 2
# Running data on werdepe01: record 336 of 9301
# 1
# Running data on whitemi01: record 337 of 9301
# 1
# Running data on wymanfr01: record 338 of 9301
# 1
# Running data on baldwki01: record 339 of 9301
# 1
# Running data on conwape01: record 340 of 9301
# 6
# Running data on dailyed01: record 341 of 9301
# 10
# Running data on foleyjo01: record 342 of 9301
# 1
# Running data on hallsch01: record 343 of 9301
# 1
# Running data on healyjo01: record 344 of 9301
# 10
# Running data on hoffojo01: record 345 of 9301
# 2
# Running data on hughebi01: record 346 of 9301
# 1
# Running data on kennete01: record 347 of 9301
# 3
# Running data on knoufed01: record 348 of 9301
# 7
# Running data on lovetto01: record 349 of 9301
# 6
# Running data on maculji01: record 350 of 9301
# 2
# Running data on maysal01: record 351 of 9301
# 6
# Running data on mccaf01: record 352 of 9301
# 1
# Running data on orrda01: record 353 of 9301
# 1
# Running data on palme01: record 354 of 9301
# 1
# Running data on pechige01: record 355 of 9301
# 3
# Running data on peoplji01: record 356 of 9301
# 1
# Running data on ramseto01: record 357 of 9301
# 7
# Running data on richada01: record 358 of 9301
# 3
# Running data on richaha01: record 359 of 9301
# 2
# Running data on rosemch01: record 360 of 9301
# 3
# Running data on sewared01: record 361 of 9301
# 6
# Running data on stellbi01: record 362 of 9301
# 1
# Running data on stemmbi01: record 363 of 9301
# 4
# Running data on wardjo03: record 364 of 9301
# 1
# Running data on wetzesh01: record 365 of 9301
# 1
# Running data on williwa01: record 366 of 9301
# 1
# Running data on woodpe01: record 367 of 9301
# 2
# Running data on bickhda01: record 368 of 9301
# 1
# Running data on bierblo01: record 369 of 9301
# 3
# Running data on bishobi01: record 370 of 9301
# 3
# Running data on brookha01: record 371 of 9301
# 1
# Running data on chambel01: record 372 of 9301
# 12
# Running data on clarked01: record 373 of 9301
# 1
# Running data on conwadi01: record 374 of 9301
# 3
# Running data on devliji02: record 375 of 9301
# 4
# Running data on flynnjo02: record 376 of 9301
# 1
# Running data on fulleed01: record 377 of 9301
# 1
# Running data on fulmech02: record 378 of 9301
# 1
# Running data on gessnch01: record 379 of 9301
# 1
# Running data on gilmofr01: record 380 of 9301
# 3
# Running data on gravefr01: record 381 of 9301
# 1
# Running data on handiji01: record 382 of 9301
# 1
# Running data on hartbi01: record 383 of 9301
# 8
# Running data on housefr01: record 384 of 9301
# 1
# Running data on hudsona01: record 385 of 9301
# 4
# Running data on hyndmji01: record 386 of 9301
# 1
# Running data on irwinbi01: record 387 of 9301
# 1
# Running data on keefege01: record 388 of 9301
# 6
# Running data on kilroma01: record 389 of 9301
# 10
# Running data on kingsi01: record 390 of 9301
# 11
# Running data on madigto01: record 391 of 9301
# 1
# Running data on murphjo02: record 392 of 9301
# 4
# Running data on nealejo01: record 393 of 9301
# 4
# Running data on oconnpa01: record 394 of 9301
# 1
# Running data on parsoch01: record 395 of 9301
# 3
# Running data on pinknge01: record 396 of 9301
# 1
# Running data on reardje02: record 397 of 9301
# 2
# Running data on ryanji01: record 398 of 9301
# 5
# Running data on scottmi01: record 399 of 9301
# 1
# Running data on seeryem01: record 400 of 9301
# 1
# Running data on shaffjo01: record 401 of 9301
# 2
# Running data on smithbi03: record 402 of 9301
# 1
# Running data on smithel01: record 403 of 9301
# 7
# Running data on smithre01: record 404 of 9301
# 2
# Running data on stephcl01: record 405 of 9301
# 2
# Running data on straujo02: record 406 of 9301
# 1
# Running data on strikjo01: record 407 of 9301
# 1
# Running data on titcoca01: record 408 of 9301
# 6
# Running data on toolest01: record 409 of 9301
# 4
# Running data on twitcla01: record 410 of 9301
# 7
# Running data on whitebi02: record 411 of 9301
# 1
# Running data on winkege01: record 412 of 9301
# 1
# Running data on yingljo01: record 413 of 9301
# 1
# Running data on zay01: record 414 of 9301
# 1
# Running data on baldwma01: record 415 of 9301
# 8
# Running data on beatied01: record 416 of 9301
# 5
# Running data on burkebi01: record 417 of 9301
# 1
# Running data on caseybi01: record 418 of 9301
# 1
# Running data on chapmfr01: record 419 of 9301
# 1
# Running data on crowebi01: record 420 of 9301
# 3
# Running data on cunnibe01: record 421 of 9301
# 13
# Running data on faganbi01: record 422 of 9301
# 2
# Running data on fast01: record 423 of 9301
# 1
# Running data on fieldjo01: record 424 of 9301
# 1
# Running data on gardnbi01: record 425 of 9301
# 1
# Running data on geissem01: record 426 of 9301
# 1
# Running data on georgbi01: record 427 of 9301
# 3
# Running data on gilksbo01: record 428 of 9301
# 3
# Running data on grubehe01: record 429 of 9301
# 5
# Running data on jonesch01: record 430 of 9301
# 1
# Running data on keatibo01: record 431 of 9301
# 1
# Running data on leitndo01: record 432 of 9301
# 1
# Running data on maddeki01: record 433 of 9301
# 6
# Running data on mattimi01: record 434 of 9301
# 5
# Running data on mcgeaja01: record 435 of 9301
# 3
# Running data on mcmulge01: record 436 of 9301
# 1
# Running data on morriha01: record 437 of 9301
# 1
# Running data on morrimi01: record 438 of 9301
# 4
# Running data on obrieda01: record 439 of 9301
# 1
# Running data on obrieto01: record 440 of 9301
# 1
# Running data on pettibo01: record 441 of 9301
# 1
# Running data on roachjo01: record 442 of 9301
# 1
# Running data on ryancy01: record 443 of 9301
# 2
# Running data on scheifr01: record 444 of 9301
# 1
# Running data on sheami01: record 445 of 9301
# 1
# Running data on shrevle01: record 446 of 9301
# 4
# Running data on sowdejo01: record 447 of 9301
# 3
# Running data on spragch01: record 448 of 9301
# 3
# Running data on sullima01: record 449 of 9301
# 1
# Running data on swababi01: record 450 of 9301
# 1
# Running data on tebeage01: record 451 of 9301
# 2
# Running data on tiernmi01: record 452 of 9301
# 1
# Running data on vanhage01: record 453 of 9301
# 9
# Running data on watsomo01: record 454 of 9301
# 1
# Running data on weyhigu01: record 455 of 9301
# 18
# Running data on widnewi01: record 456 of 9301
# 5
# Running data on blairbi01: record 457 of 9301
# 1
# Running data on borchge01: record 458 of 9301
# 2
# Running data on brynato01: record 459 of 9301
# 2
# Running data on burdibi01: record 460 of 9301
# 2
# Running data on clarkda01: record 461 of 9301
# 8
# Running data on dennyje01: record 462 of 9301
# 1
# Running data on dwyerfr01: record 463 of 9301
# 14
# Running data on ehretre01: record 464 of 9301
# 11
# Running data on ewingjo01: record 465 of 9301
# 4
# Running data on freemju01: record 466 of 9301
# 1
# Running data on gamblbo01: record 467 of 9301
# 1
# Running data on gleaski01: record 468 of 9301
# 9
# Running data on greenjo01: record 469 of 9301
# 1
# Running data on gumbead01: record 470 of 9301
# 10
# Running data on haddoge01: record 471 of 9301
# 8
# Running data on hafnefr01: record 472 of 9301
# 1
# Running data on hoffmfr01: record 473 of 9301
# 1
# Running data on hughemi01: record 474 of 9301
# 4
# Running data on keased01: record 475 of 9301
# 1
# Running data on kilromi01: record 476 of 9301
# 2
# Running data on knellph01: record 477 of 9301
# 9
# Running data on krockgu01: record 478 of 9301
# 5
# Running data on mainswi01: record 479 of 9301
# 4
# Running data on oberldo01: record 480 of 9301
# 1
# Running data on obrieda02: record 481 of 9301
# 4
# Running data on proesge01: record 482 of 9301
# 1
# Running data on sandebe01: record 483 of 9301
# 5
# Running data on schoeju01: record 484 of 9301
# 1
# Running data on shawsa01: record 485 of 9301
# 2
# Running data on shochge01: record 486 of 9301
# 1
# Running data on sowdebi01: record 487 of 9301
# 4
# Running data on staleha01: record 488 of 9301
# 9
# Running data on stratsc01: record 489 of 9301
# 10
# Running data on tenerjo01: record 490 of 9301
# 3
# Running data on tucketo01: record 491 of 9301
# 2
# Running data on viaule01: record 492 of 9301
# 8
# Running data on walkege01: record 493 of 9301
# 1
# Running data on weyhijo01: record 494 of 9301
# 2
# Running data on whitapa01: record 495 of 9301
# 2
# Running data on anderda01: record 496 of 9301
# 3
# Running data on anderva01: record 497 of 9301
# 4
# Running data on batesjo01: record 498 of 9301
# 1
# Running data on bausege01: record 499 of 9301
# 1
# Running data on beamal01: record 500 of 9301
# 1
# Running data on bellch01: record 501 of 9301
# 3
# Running data on conovte01: record 502 of 9301
# 1
# Running data on daleybi01: record 503 of 9301
# 3
# Running data on daybi01: record 504 of 9301
# 3
# Running data on dunnian01: record 505 of 9301
# 2
# Running data on duryeje01: record 506 of 9301
# 7
# Running data on eastoja01: record 507 of 9301
# 7
# Running data on fannija01: record 508 of 9301
# 2
# Running data on feeja01: record 509 of 9301
# 1
# Running data on fersoal01: record 510 of 9301
# 3
# Running data on garfibi01: record 511 of 9301
# 2
# Running data on gastrha01: record 512 of 9301
# 8
# Running data on goetzge01: record 513 of 9301
# 1
# Running data on hatfigi01: record 514 of 9301
# 3
# Running data on jonesal01: record 515 of 9301
# 5
# Running data on krummal01: record 516 of 9301
# 1
# Running data on ladewst01: record 517 of 9301
# 1
# Running data on mccarjo01: record 518 of 9301
# 1
# Running data on mcdermi01: record 519 of 9301
# 1
# Running data on mcmahsa01: record 520 of 9301
# 10
# Running data on nashbi01: record 521 of 9301
# 2
# Running data on pearsfr01: record 522 of 9301
# 2
# Running data on pettych01: record 523 of 9301
# 4
# Running data on raymoha01: record 524 of 9301
# 1
# Running data on robinbi01: record 525 of 9301
# 1
# Running data on rusieam01: record 526 of 9301
# 10
# Running data on sprined01: record 527 of 9301
# 1
# Running data on stiveja01: record 528 of 9301
# 11
# Running data on sullimi02: record 529 of 9301
# 12
# Running data on swartpa01: record 530 of 9301
# 1
# Running data on thornjo01: record 531 of 9301
# 3
# Running data on abbotda01: record 532 of 9301
# 1
# Running data on bakerki01: record 533 of 9301
# 5
# Running data on bartsch01: record 534 of 9301
# 1
# Running data on beeched01: record 535 of 9301
# 1
# Running data on blauvhe01: record 536 of 9301
# 1
# Running data on bowmasu01: record 537 of 9301
# 3
# Running data on buckljo01: record 538 of 9301
# 1
# Running data on burkeje01: record 539 of 9301
# 3
# Running data on calihwi01: record 540 of 9301
# 2
# Running data on clarksp01: record 541 of 9301
# 1
# Running data on colemjo02: record 542 of 9301
# 1
# Running data on cotteda01: record 543 of 9301
# 1
# Running data on coughro01: record 544 of 9301
# 2
# Running data on dailevi01: record 545 of 9301
# 1
# Running data on daniepe01: record 546 of 9301
# 2
# Running data on demarfr01: record 547 of 9301
# 1
# Running data on dewalch01: record 548 of 9301
# 1
# Running data on doefr01: record 549 of 9301
# 2
# Running data on dolanjo01: record 550 of 9301
# 5
# Running data on dotyba01: record 551 of 9301
# 1
# Running data on dowseto01: record 552 of 9301
# 1
# Running data on duzenbi01: record 553 of 9301
# 1
# Running data on eiteled01: record 554 of 9301
# 2
# Running data on esperdu01: record 555 of 9301
# 13
# Running data on fieldji01: record 556 of 9301
# 1
# Running data on fitzgjo01: record 557 of 9301
# 1
# Running data on fordto01: record 558 of 9301
# 2
# Running data on francos01: record 559 of 9301
# 1
# Running data on germale01: record 560 of 9301
# 7
# Running data on gibsoro01: record 561 of 9301
# 2
# Running data on gleasbi02: record 562 of 9301
# 1
# Running data on goodahe01: record 563 of 9301
# 1
# Running data on graych01: record 564 of 9301
# 1
# Running data on greened01: record 565 of 9301
# 1
# Running data on grimjo01: record 566 of 9301
# 1
# Running data on gumbebi01: record 567 of 9301
# 3
# Running data on hartbi02: record 568 of 9301
# 1
# Running data on haynefr01: record 569 of 9301
# 1
# Running data on heardch01: record 570 of 9301
# 1
# Running data on helmbho01: record 571 of 9301
# 1
# Running data on hemmige01: record 572 of 9301
# 11
# Running data on hustebi01: record 573 of 9301
# 1
# Running data on joneshe02: record 574 of 9301
# 1
# Running data on jonesmi01: record 575 of 9301
# 1
# Running data on keefejo01: record 576 of 9301
# 1
# Running data on keffefr01: record 577 of 9301
# 1
# Running data on knausfr01: record 578 of 9301
# 5
# Running data on lacke01: record 579 of 9301
# 1
# Running data on lawsoal01: record 580 of 9301
# 2
# Running data on lewis01: record 581 of 9301
# 1
# Running data on lincoez01: record 582 of 9301
# 2
# Running data on lubypa01: record 583 of 9301
# 4
# Running data on lyonsha01: record 584 of 9301
# 1
# Running data on lyonsto01: record 585 of 9301
# 1
# Running data on marsed01: record 586 of 9301
# 1
# Running data on mcculch01: record 587 of 9301
# 2
# Running data on mcfetja01: record 588 of 9301
# 2
# Running data on mcgilwi01: record 589 of 9301
# 8
# Running data on mcguide01: record 590 of 9301
# 1
# Running data on meakige01: record 591 of 9301
# 5
# Running data on millebo01: record 592 of 9301
# 2
# Running data on murphbo01: record 593 of 9301
# 2
# Running data on nichoki01: record 594 of 9301
# 16
# Running data on nicolge01: record 595 of 9301
# 4
# Running data on oneiled01: record 596 of 9301
# 2
# Running data on orourmi01: record 597 of 9301
# 1
# Running data on osborfr01: record 598 of 9301
# 1
# Running data on phillbi02: record 599 of 9301
# 7
# Running data on powerji01: record 600 of 9301
# 1
# Running data on pricebi01: record 601 of 9301
# 1
# Running data on rhinebi01: record 602 of 9301
# 9
# Running data on schmicr01: record 603 of 9301
# 6
# Running data on sharrja01: record 604 of 9301
# 4
# Running data on smithfr02: record 605 of 9301
# 1
# Running data on staffge01: record 606 of 9301
# 1
# Running data on stechch01: record 607 of 9301
# 1
# Running data on steined01: record 608 of 9301
# 8
# Running data on sterljo01: record 609 of 9301
# 1
# Running data on stineha01: record 610 of 9301
# 1
# Running data on sullibi02: record 611 of 9301
# 1
# Running data on sundabi01: record 612 of 9301
# 1
# Running data on taberjo01: record 613 of 9301
# 1
# Running data on vicketo01: record 614 of 9301
# 4
# Running data on vonfrto01: record 615 of 9301
# 1
# Running data on wadswja01: record 616 of 9301
# 4
# Running data on welchcu01: record 617 of 9301
# 1
# Running data on whitrbi01: record 618 of 9301
# 5
# Running data on willigu01: record 619 of 9301
# 1
# Running data on youngcy01: record 620 of 9301
# 23
# Running data on zieglge01: record 621 of 9301
# 1
# Running data on boonege01: record 622 of 9301
# 1
# Running data on breitte01: record 623 of 9301
# 11
# Running data on burreha01: record 624 of 9301
# 1
# Running data on carseki01: record 625 of 9301
# 12
# Running data on cassied01: record 626 of 9301
# 2
# Running data on clarkda02: record 627 of 9301
# 7
# Running data on daviege01: record 628 of 9301
# 4
# Running data on davisge01: record 629 of 9301
# 1
# Running data on doranjo01: record 630 of 9301
# 1
# Running data on dukema01: record 631 of 9301
# 1
# Running data on fitzgjo02: record 632 of 9301
# 1
# Running data on fitzgwa01: record 633 of 9301
# 2
# Running data on freembu01: record 634 of 9301
# 2
# Running data on gormljo01: record 635 of 9301
# 1
# Running data on griffcl01: record 636 of 9301
# 21
# Running data on hugheji01: record 637 of 9301
# 7
# Running data on inksbe01: record 638 of 9301
# 8
# Running data on keenaki01: record 639 of 9301
# 1
# Running data on kileyjo01: record 640 of 9301
# 1
# Running data on killefr01: record 641 of 9301
# 12
# Running data on killehe01: record 642 of 9301
# 1
# Running data on klingbi01: record 643 of 9301
# 3
# Running data on leipeja01: record 644 of 9301
# 1
# Running data on lowebo01: record 645 of 9301
# 1
# Running data on lystobi01: record 646 of 9301
# 2
# Running data on maceji01: record 647 of 9301
# 1
# Running data on meekijo01: record 648 of 9301
# 12
# Running data on quarlbi01: record 649 of 9301
# 2
# Running data on rettgge01: record 650 of 9301
# 3
# Running data on sayloph01: record 651 of 9301
# 1
# Running data on schuljo01: record 652 of 9301
# 1
# Running data on shearjo01: record 653 of 9301
# 1
# Running data on slagljo01: record 654 of 9301
# 1
# Running data on sulliji01: record 655 of 9301
# 6
# Running data on tayloja01: record 656 of 9301
# 9
# Running data on vaughfa01: record 657 of 9301
# 1
# Running data on abbeybe01: record 658 of 9301
# 6
# Running data on campki01: record 659 of 9301
# 2
# Running data on clausfr01: record 660 of 9301
# 5
# Running data on cobbge01: record 661 of 9301
# 1
# Running data on cuppyni01: record 662 of 9301
# 10
# Running data on daubda01: record 663 of 9301
# 6
# Running data on demilha01: record 664 of 9301
# 1
# Running data on elyha01: record 665 of 9301
# 1
# Running data on gilbebi01: record 666 of 9301
# 1
# Running data on grifffr01: record 667 of 9301
# 2
# Running data on hawkebi01: record 668 of 9301
# 4
# Running data on hawlepi01: record 669 of 9301
# 10
# Running data on hollibu01: record 670 of 9301
# 2
# Running data on hollijo01: record 671 of 9301
# 1
# Running data on jonesbu01: record 672 of 9301
# 3
# Running data on kennebr01: record 673 of 9301
# 12
# Running data on menefjo01: record 674 of 9301
# 10
# Running data on stephbe01: record 675 of 9301
# 4
# Running data on thompwi01: record 676 of 9301
# 1
# Running data on willito01: record 677 of 9301
# 2
# Running data on woodcfr01: record 678 of 9301
# 1
# Running data on youngjb01: record 679 of 9301
# 1
# Running data on bannoji01: record 680 of 9301
# 3
# Running data on brownst01: record 681 of 9301
# 3
# Running data on colcoto01: record 682 of 9301
# 4
# Running data on coylebi01: record 683 of 9301
# 1
# Running data on crossle01: record 684 of 9301
# 2
# Running data on darbyge01: record 685 of 9301
# 1
# Running data on donahre01: record 686 of 9301
# 14
# Running data on donnefr01: record 687 of 9301
# 1
# Running data on fishech04: record 688 of 9301
# 7
# Running data on garryji01: record 689 of 9301
# 1
# Running data on graffjo01: record 690 of 9301
# 1
# Running data on hastich01: record 691 of 9301
# 4
# Running data on johnsab01: record 692 of 9301
# 1
# Running data on lucidco01: record 693 of 9301
# 6
# Running data on mauckha01: record 694 of 9301
# 1
# Running data on mcgingu01: record 695 of 9301
# 2
# Running data on mcnabed01: record 696 of 9301
# 1
# Running data on oconnfr01: record 697 of 9301
# 1
# Running data on parkedo01: record 698 of 9301
# 4
# Running data on parroto01: record 699 of 9301
# 5
# Running data on rhodebi01: record 700 of 9301
# 1
# Running data on scheija01: record 701 of 9301
# 2
# Running data on sharrge01: record 702 of 9301
# 2
# Running data on sigsbse01: record 703 of 9301
# 1
# Running data on staffjo01: record 704 of 9301
# 1
# Running data on stockot01: record 705 of 9301
# 5
# Running data on virtuja01: record 706 of 9301
# 2
# Running data on yostgu01: record 707 of 9301
# 1
# Running data on blankfr01: record 708 of 9301
# 1
# Running data on boydja01: record 709 of 9301
# 3
# Running data on burrial01: record 710 of 9301
# 1
# Running data on callani01: record 711 of 9301
# 8
# Running data on eganri01: record 712 of 9301
# 1
# Running data on figgefr01: record 713 of 9301
# 1
# Running data on flynnca01: record 714 of 9301
# 3
# Running data on fournhe01: record 715 of 9301
# 1
# Running data on frankch01: record 716 of 9301
# 1
# Running data on harpege01: record 717 of 9301
# 2
# Running data on hawlesc01: record 718 of 9301
# 1
# Running data on hodsoge01: record 719 of 9301
# 2
# Running data on horneja01: record 720 of 9301
# 1
# Running data on johnsjo01: record 721 of 9301
# 1
# Running data on jordaha01: record 722 of 9301
# 2
# Running data on korwaji01: record 723 of 9301
# 2
# Running data on lampehe01: record 724 of 9301
# 2
# Running data on lukenal01: record 725 of 9301
# 1
# Running data on malarjo01: record 726 of 9301
# 6
# Running data on masoner01: record 727 of 9301
# 1
# Running data on mcgui01: record 728 of 9301
# 1
# Running data on mercewi01: record 729 of 9301
# 9
# Running data on peitzhe01: record 730 of 9301
# 3
# Running data on peppeha01: record 731 of 9301
# 1
# Running data on pfannbi01: record 732 of 9301
# 1
# Running data on smithto02: record 733 of 9301
# 4
# Running data on sommean01: record 734 of 9301
# 1
# Running data on stultge01: record 735 of 9301
# 1
# Running data on tanneje01: record 736 of 9301
# 16
# Running data on thomato01: record 737 of 9301
# 3
# Running data on turnetu01: record 738 of 9301
# 1
# Running data on underfr01: record 739 of 9301
# 1
# Running data on wallabo01: record 740 of 9301
# 4
# Running data on westehu01: record 741 of 9301
# 1
# Running data on westfr01: record 742 of 9301
# 1
# Running data on wynnebi01: record 743 of 9301
# 1
# Running data on baileki01: record 744 of 9301
# 1
# Running data on banksbi01: record 745 of 9301
# 2
# Running data on beamer01: record 746 of 9301
# 1
# Running data on boswean01: record 747 of 9301
# 2
# Running data on buckied01: record 748 of 9301
# 1
# Running data on childbi01: record 749 of 9301
# 1
# Running data on colemjo03: record 750 of 9301
# 1
# Running data on corbejo01: record 751 of 9301
# 4
# Running data on cronija01: record 752 of 9301
# 9
# Running data on dohened01: record 753 of 9301
# 10
# Running data on dolanco01: record 754 of 9301
# 4
# Running data on forembr01: record 755 of 9301
# 3
# Running data on frienda01: record 756 of 9301
# 4
# Running data on gannogu01: record 757 of 9301
# 1
# Running data on gardnji01: record 758 of 9301
# 5
# Running data on gettito01: record 759 of 9301
# 1
# Running data on gilrojo01: record 760 of 9301
# 2
# Running data on hewitja01: record 761 of 9301
# 1
# Running data on hoffebi01: record 762 of 9301
# 7
# Running data on holmedu01: record 763 of 9301
# 2
# Running data on kissibi01: record 764 of 9301
# 4
# Running data on mccreto01: record 765 of 9301
# 3
# Running data on mcdermi02: record 766 of 9301
# 4
# Running data on mcdoude01: record 767 of 9301
# 2
# Running data on mcdousa01: record 768 of 9301
# 2
# Running data on mcfarda01: record 769 of 9301
# 3
# Running data on mcfarmo01: record 770 of 9301
# 2
# Running data on mcjamdo01: record 771 of 9301
# 6
# Running data on molesca01: record 772 of 9301
# 1
# Running data on moransa01: record 773 of 9301
# 1
# Running data on orthal01: record 774 of 9301
# 16
# Running data on pondar01: record 775 of 9301
# 4
# Running data on purneos01: record 776 of 9301
# 1
# Running data on sextofr01: record 777 of 9301
# 1
# Running data on thornwa01: record 778 of 9301
# 4
# Running data on whitede02: record 779 of 9301
# 1
# Running data on wilsoze01: record 780 of 9301
# 6
# Running data on wrighda01: record 781 of 9301
# 2
# Running data on abbeych01: record 782 of 9301
# 1
# Running data on bowency01: record 783 of 9301
# 1
# Running data on briggbu01: record 784 of 9301
# 5
# Running data on campfsa01: record 785 of 9301
# 1
# Running data on daviswi01: record 786 of 9301
# 1
# Running data on emigch01: record 787 of 9301
# 1
# Running data on frasech01: record 788 of 9301
# 15
# Running data on garvine01: record 789 of 9301
# 9
# Running data on gearda01: record 790 of 9301
# 2
# Running data on gettich01: record 791 of 9301
# 4
# Running data on goarjo01: record 792 of 9301
# 2
# Running data on hallmbi01: record 793 of 9301
# 1
# Running data on hermaar01: record 794 of 9301
# 2
# Running data on hillbi01: record 795 of 9301
# 6
# Running data on hortoel01: record 796 of 9301
# 2
# Running data on jordach01: record 797 of 9301
# 1
# Running data on keeneha01: record 798 of 9301
# 1
# Running data on kittrma01: record 799 of 9301
# 1
# Running data on klobefr01: record 800 of 9301
# 5
# Running data on kostajo01: record 801 of 9301
# 1
# Running data on lewiste01: record 802 of 9301
# 6
# Running data on mcallsp01: record 803 of 9301
# 4
# Running data on nopsje01: record 804 of 9301
# 7
# Running data on nortoef01: record 805 of 9301
# 2
# Running data on payneha01: record 806 of 9301
# 4
# Running data on reidybi01: record 807 of 9301
# 7
# Running data on seymocy01: record 808 of 9301
# 6
# Running data on tebeapa01: record 809 of 9301
# 1
# Running data on wheelge01: record 810 of 9301
# 4
# Running data on woodjo01: record 811 of 9301
# 1
# Running data on amoledo01: record 812 of 9301
# 2
# Running data on beckebo01: record 813 of 9301
# 2
# Running data on blackge01: record 814 of 9301
# 1
# Running data on bresnro01: record 815 of 9301
# 3
# Running data on brownch01: record 816 of 9301
# 1
# Running data on brownjo02: record 817 of 9301
# 1
# Running data on clarkhe01: record 818 of 9301
# 2
# Running data on cogandi01: record 819 of 9301
# 3
# Running data on colempe01: record 820 of 9301
# 2
# Running data on dammabi01: record 821 of 9301
# 3
# Running data on denzero01: record 822 of 9301
# 2
# Running data on dowlipe01: record 823 of 9301
# 5
# Running data on dunklda01: record 824 of 9301
# 6
# Running data on dunnja01: record 825 of 9301
# 9
# Running data on evansro01: record 826 of 9301
# 8
# Running data on fifieja01: record 827 of 9301
# 4
# Running data on grimejo01: record 828 of 9301
# 1
# Running data on hickmch01: record 829 of 9301
# 6
# Running data on johnsyo01: record 830 of 9301
# 2
# Running data on jonesji01: record 831 of 9301
# 2
# Running data on lippto01: record 832 of 9301
# 1
# Running data on mageebi01: record 833 of 9301
# 9
# Running data on mahonmi01: record 834 of 9301
# 1
# Running data on millebe01: record 835 of 9301
# 1
# Running data on pappajo01: record 836 of 9301
# 1
# Running data on powelja01: record 837 of 9301
# 17
# Running data on sparktu01: record 838 of 9301
# 13
# Running data on stanljo02: record 839 of 9301
# 3
# Running data on sudhowi01: record 840 of 9301
# 11
# Running data on swaimcy01: record 841 of 9301
# 2
# Running data on wadderu01: record 842 of 9301
# 14
# Running data on altroni01: record 843 of 9301
# 18
# Running data on batesfr01: record 844 of 9301
# 3
# Running data on callajo02: record 845 of 9301
# 1
# Running data on carribi01: record 846 of 9301
# 5
# Running data on connbe01: record 847 of 9301
# 2
# Running data on dinnebi01: record 848 of 9301
# 13
# Running data on donovbi01: record 849 of 9301
# 18
# Running data on dugglbi01: record 850 of 9301
# 10
# Running data on gannojo01: record 851 of 9301
# 1
# Running data on gastowe01: record 852 of 9301
# 2
# Running data on gillpge01: record 853 of 9301
# 1
# Running data on hansffc01: record 854 of 9301
# 1
# Running data on hoppele01: record 855 of 9301
# 1
# Running data on howelha01: record 856 of 9301
# 13
# Running data on hugheja01: record 857 of 9301
# 4
# Running data on isbelfr01: record 858 of 9301
# 5
# Running data on jonesco01: record 859 of 9301
# 4
# Running data on katolja01: record 860 of 9301
# 5
# Running data on kelbge01: record 861 of 9301
# 1
# Running data on kitsofr01: record 862 of 9301
# 11
# Running data on leevesa01: record 863 of 9301
# 13
# Running data on mahaflo01: record 864 of 9301
# 1
# Running data on maupiha01: record 865 of 9301
# 2
# Running data on mcbripe01: record 866 of 9301
# 2
# Running data on mckenki01: record 867 of 9301
# 2
# Running data on millera01: record 868 of 9301
# 2
# Running data on murphed01: record 869 of 9301
# 4
# Running data on phylebi01: record 870 of 9301
# 3
# Running data on piattwi01: record 871 of 9301
# 7
# Running data on rosebze01: record 872 of 9301
# 2
# Running data on sullisu01: record 873 of 9301
# 1
# Running data on sutthja01: record 874 of 9301
# 7
# Running data on tayloja02: record 875 of 9301
# 11
# Running data on toddfr01: record 876 of 9301
# 1
# Running data on weberch01: record 877 of 9301
# 1
# Running data on willipo01: record 878 of 9301
# 5
# Running data on willivi01: record 879 of 9301
# 13
# Running data on woodswa01: record 880 of 9301
# 3
# Running data on yeagejo01: record 881 of 9301
# 6
# Running data on baileha01: record 882 of 9301
# 2
# Running data on bernhbi01: record 883 of 9301
# 10
# Running data on brashki01: record 884 of 9301
# 1
# Running data on chesbja01: record 885 of 9301
# 12
# Running data on colliha01: record 886 of 9301
# 1
# Running data on donlimi01: record 887 of 9301
# 2
# Running data on fauvecl01: record 888 of 9301
# 1
# Running data on fishele01: record 889 of 9301
# 1
# Running data on flahepa02: record 890 of 9301
# 10
# Running data on friskem01: record 891 of 9301
# 2
# Running data on garonwi01: record 892 of 9301
# 1
# Running data on gingbi01: record 893 of 9301
# 1
# Running data on graych02: record 894 of 9301
# 1
# Running data on hahnno01: record 895 of 9301
# 8
# Running data on harpeja01: record 896 of 9301
# 9
# Running data on herrile01: record 897 of 9301
# 1
# Running data on kneppch01: record 898 of 9301
# 1
# Running data on kolbed01: record 899 of 9301
# 1
# Running data on leithbi01: record 900 of 9301
# 1
# Running data on lochhha01: record 901 of 9301
# 1
# Running data on mcginjo01: record 902 of 9301
# 11
# Running data on mcparfr01: record 903 of 9301
# 1
# Running data on parkeja01: record 904 of 9301
# 1
# Running data on phillde01: record 905 of 9301
# 13
# Running data on riddldo01: record 906 of 9301
# 1
# Running data on roachsk01: record 907 of 9301
# 1
# Running data on sechrdo01: record 908 of 9301
# 1
# Running data on stahlch01: record 909 of 9301
# 1
# Running data on streios01: record 910 of 9301
# 2
# Running data on wilheha01: record 911 of 9301
# 1
# Running data on wilsohi01: record 912 of 9301
# 4
# Running data on chambro01: record 913 of 9301
# 1
# Running data on easonma01: record 914 of 9301
# 7
# Running data on harveza01: record 915 of 9301
# 2
# Running data on hugheto01: record 916 of 9301
# 15
# Running data on hustibe01: record 917 of 9301
# 4
# Running data on mathech01: record 918 of 9301
# 18
# Running data on mclauwa01: record 919 of 9301
# 3
# Running data on newtodo01: record 920 of 9301
# 9
# Running data on pittito01: record 921 of 9301
# 8
# Running data on pooleed01: record 922 of 9301
# 6
# Running data on scotted01: record 923 of 9301
# 2
# Running data on stimmar01: record 924 of 9301
# 3
# Running data on taylodu01: record 925 of 9301
# 10
# Running data on thomaro01: record 926 of 9301
# 1
# Running data on wagneho01: record 927 of 9301
# 2
# Running data on bakerbo01: record 928 of 9301
# 2
# Running data on bevilbe01: record 929 of 9301
# 1
# Running data on brackja01: record 930 of 9301
# 1
# Running data on bradlbi01: record 931 of 9301
# 1
# Running data on braggdi01: record 932 of 9301
# 1
# Running data on burnsfa01: record 933 of 9301
# 1
# Running data on casech01: record 934 of 9301
# 4
# Running data on cristbi01: record 935 of 9301
# 1
# Running data on deegadu01: record 936 of 9301
# 1
# Running data on donovto01: record 937 of 9301
# 1
# Running data on dupeefr01: record 938 of 9301
# 1
# Running data on felixha01: record 939 of 9301
# 2
# Running data on ferguch02: record 940 of 9301
# 1
# Running data on guesewh01: record 941 of 9301
# 1
# Running data on heismcr01: record 942 of 9301
# 3
# Running data on hestela01: record 943 of 9301
# 1
# Running data on highed01: record 944 of 9301
# 1
# Running data on karnsbi01: record 945 of 9301
# 1
# Running data on kelluwi01: record 946 of 9301
# 3
# Running data on lawsobo01: record 947 of 9301
# 2
# Running data on leewa01: record 948 of 9301
# 4
# Running data on leitndu01: record 949 of 9301
# 4
# Running data on livinja01: record 950 of 9301
# 1
# Running data on loospe01: record 951 of 9301
# 1
# Running data on mcaleja01: record 952 of 9301
# 1
# Running data on mcaleji01: record 953 of 9301
# 1
# Running data on mccange01: record 954 of 9301
# 2
# Running data on mcfadba01: record 955 of 9301
# 2
# Running data on mcneaha01: record 956 of 9301
# 1
# Running data on mcphejo01: record 957 of 9301
# 2
# Running data on merrige01: record 958 of 9301
# 2
# Running data on millero01: record 959 of 9301
# 5
# Running data on millibi01: record 960 of 9301
# 2
# Running data on millswi01: record 961 of 9301
# 1
# Running data on mitchfr01: record 962 of 9301
# 7
# Running data on mooreea01: record 963 of 9301
# 16
# Running data on morrifr01: record 964 of 9301
# 2
# Running data on oneilmi01: record 965 of 9301
# 4
# Running data on owenfr01: record 966 of 9301
# 8
# Running data on patteca01: record 967 of 9301
# 9
# Running data on pattero01: record 968 of 9301
# 7
# Running data on planked01: record 969 of 9301
# 17
# Running data on prentge01: record 970 of 9301
# 3
# Running data on scottdi01: record 971 of 9301
# 1
# Running data on sieveed01: record 972 of 9301
# 7
# Running data on skopejo01: record 973 of 9301
# 2
# Running data on smithhe01: record 974 of 9301
# 1
# Running data on swormle01: record 975 of 9301
# 3
# Running data on townsha01: record 976 of 9301
# 6
# Running data on vanzaik01: record 977 of 9301
# 2
# Running data on volzja01: record 978 of 9301
# 3
# Running data on whitedo01: record 979 of 9301
# 13
# Running data on wickebo01: record 980 of 9301
# 8
# Running data on wiltssn01: record 981 of 9301
# 5
# Running data on wintege01: record 982 of 9301
# 9
# Running data on wrighge02: record 983 of 9301
# 5
# Running data on yerkest01: record 984 of 9301
# 4
# Running data on adamsjo01: record 985 of 9301
# 1
# Running data on adkindo01: record 986 of 9301
# 2
# Running data on becklja01: record 987 of 9301
# 1
# Running data on blewebo01: record 988 of 9301
# 1
# Running data on burkejo02: record 989 of 9301
# 1
# Running data on butleik01: record 990 of 9301
# 1
# Running data on carnepa01: record 991 of 9301
# 3
# Running data on clarkgi01: record 992 of 9301
# 1
# Running data on coaklan01: record 993 of 9301
# 10
# Running data on currasa01: record 994 of 9301
# 1
# Running data on curricl01: record 995 of 9301
# 4
# Running data on cushmha01: record 996 of 9301
# 1
# Running data on deinipe01: record 997 of 9301
# 1
# Running data on dornegu01: record 998 of 9301
# 7
# Running data on dressbo01: record 999 of 9301
# 1
# Running data on dunhawi01: record 1000 of 9301
# 1
# Running data on durhajo01: record 1001 of 9301
# 1
# Running data on eganwi01: record 1002 of 9301
# 3
# ...
# 2
# Running data on bradlar01: record 8974 of 9301
# 2
# Running data on brighja01: record 8975 of 9301
# 1
# Running data on broadmi01: record 8976 of 9301
# 2
# Running data on burawda01: record 8977 of 9301
# 2
# Running data on burgoen02: record 8978 of 9301
# 2
# Running data on castran01: record 8979 of 9301
# 1
# Running data on castrmi01: record 8980 of 9301
# 3
# Running data on coleaj01: record 8981 of 9301
# 2
# Running data on conlead01: record 8982 of 9301
# 2
# Running data on cooneti01: record 8983 of 9301
# 1
# Running data on copelsc01: record 8984 of 9301
# 1
# Running data on cornejo01: record 8985 of 9301
# 1
# Running data on cothaca01: record 8986 of 9301
# 2
# Running data on cravyty01: record 8987 of 9301
# 2
# Running data on cunnibr02: record 8988 of 9301
# 2
# Running data on davieza01: record 8989 of 9301
# 2
# Running data on davisik02: record 8990 of 9301
# 1
# Running data on deckeja01: record 8991 of 9301
# 1
# Running data on delosab01: record 8992 of 9301
# 2
# Running data on denorch01: record 8993 of 9301
# 1
# Running data on depaujo02: record 8994 of 9301
# 1
# Running data on drakeol01: record 8995 of 9301
# 2
# Running data on duffety01: record 8996 of 9301
# 2
# Running data on dullry01: record 8997 of 9301
# 2
# Running data on edwarca01: record 8998 of 9301
# 2
# Running data on eickhje01: record 8999 of 9301
# 2
# Running data on ellinbr02: record 9000 of 9301
# 2
# Running data on faulkan01: record 9001 of 9301
# 2
# Running data on felizmi01: record 9002 of 9301
# 2
# Running data on ferreje01: record 9003 of 9301
# 1
# Running data on floreke01: record 9004 of 9301
# 2
# Running data on francje02: record 9005 of 9301
# 1
# Running data on frankni01: record 9006 of 9301
# 1
# Running data on garcija03: record 9007 of 9301
# 1
# Running data on gilmase01: record 9008 of 9301
# 2
# Running data on givenmy01: record 9009 of 9301
# 2
# Running data on godleza01: record 9010 of 9301
# 2
# Running data on goforda01: record 9011 of 9301
# 2
# Running data on gomesjo01: record 9012 of 9301
# 1
# Running data on gonzach01: record 9013 of 9301
# 2
# Running data on gonzase01: record 9014 of 9301
# 2
# Running data on goodyni01: record 9015 of 9301
# 2
# Running data on gotttr01: record 9016 of 9301
# 2
# Running data on gracema02: record 9017 of 9301
# 2
# Running data on grahajr01: record 9018 of 9301
# 2
# Running data on grayjo02: record 9019 of 9301
# 2
# Running data on guaipma01: record 9020 of 9301
# 2
# Running data on guerrde01: record 9021 of 9301
# 2
# Running data on guerrju02: record 9022 of 9301
# 2
# Running data on gurkaja01: record 9023 of 9301
# 2
# Running data on hallco01: record 9024 of 9301
# 2
# Running data on harrimi03: record 9025 of 9301
# 1
# Running data on hatlema01: record 9026 of 9301
# 1
# Running data on hesslke01: record 9027 of 9301
# 3
# Running data on hinojda01: record 9028 of 9301
# 3
# Running data on housead01: record 9029 of 9301
# 1
# Running data on ibarred01: record 9030 of 9301
# 1
# Running data on iglesra01: record 9031 of 9301
# 2
# Running data on jacksja01: record 9032 of 9301
# 1
# Running data on jackslu01: record 9033 of 9301
# 2
# Running data on johnsbr02: record 9034 of 9301
# 1
# Running data on jonesga02: record 9035 of 9301
# 1
# Running data on jungmta01: record 9036 of 9301
# 2
# Running data on kelake01: record 9037 of 9301
# 2
# Running data on kellyry01: record 9038 of 9301
# 1
# Running data on knudsgu01: record 9039 of 9301
# 1
# Running data on lambjo02: record 9040 of 9301
# 2
# Running data on larocad01: record 9041 of 9301
# 1
# Running data on lazora01: record 9042 of 9301
# 1
# Running data on leathja01: record 9043 of 9301
# 1
# Running data on leeza01: record 9044 of 9301
# 1
# Running data on leonar01: record 9045 of 9301
# 2
# Running data on liberad01: record 9046 of 9301
# 2
# Running data on lindgja01: record 9047 of 9301
# 1
# Running data on lopezjo02: record 9048 of 9301
# 1
# Running data on lorenmi01: record 9049 of 9301
# 2
# Running data on marimsu01: record 9050 of 9301
# 1
# Running data on marksma01: record 9051 of 9301
# 2
# Running data on martico01: record 9052 of 9301
# 3
# Running data on martira04: record 9053 of 9301
# 2
# Running data on matzst01: record 9054 of 9301
# 2
# Running data on mazzoco01: record 9055 of 9301
# 1
# Running data on mcculla02: record 9056 of 9301
# 2
# Running data on mcgousc01: record 9057 of 9301
# 1
# Running data on mckiran01: record 9058 of 9301
# 1
# Running data on meyeral01: record 9059 of 9301
# 3
# Running data on montafr01: record 9060 of 9301
# 1
# Running data on montgmi01: record 9061 of 9301
# 3
# Running data on moorety01: record 9062 of 9301
# 1
# Running data on morendi01: record 9063 of 9301
# 1
# Running data on morgaad01: record 9064 of 9301
# 2
# Running data on morriak01: record 9065 of 9301
# 1
# Running data on moscojo01: record 9066 of 9301
# 2
# Running data on muratto01: record 9067 of 9301
# 1
# Running data on murraco01: record 9068 of 9301
# 2
# Running data on nesbian01: record 9069 of 9301
# 1
# Running data on nicolju01: record 9070 of 9301
# 2
# Running data on nolaaa01: record 9071 of 9301
# 2
# Running data on obergsc01: record 9072 of 9301
# 2
# Running data on ogandne01: record 9073 of 9301
# 2
# Running data on olsonty01: record 9074 of 9301
# 2
# Running data on orourry01: record 9075 of 9301
# 2
# Running data on osichjo01: record 9076 of 9301
# 2
# Running data on osunaro01: record 9077 of 9301
# 2
# Running data on owenshe02: record 9078 of 9301
# 2
# Running data on pazosja01: record 9079 of 9301
# 2
# Running data on penaar01: record 9080 of 9301
# 2
# Running data on perezwi01: record 9081 of 9301
# 2
# Running data on pindebr01: record 9082 of 9301
# 2
# Running data on ramiral03: record 9083 of 9301
# 1
# Running data on ramirno01: record 9084 of 9301
# 2
# Running data on ravinjo01: record 9085 of 9301
# 2
# Running data on reaco01: record 9086 of 9301
# 3
# Running data on rearich01: record 9087 of 9301
# 1
# Running data on reedch01: record 9088 of 9301
# 1
# Running data on riverfe01: record 9089 of 9301
# 3
# Running data on roberke02: record 9090 of 9301
# 2
# Running data on robincl01: record 9091 of 9301
# 1
# Running data on robinsh01: record 9092 of 9301
# 1
# Running data on robleha01: record 9093 of 9301
# 2
# Running data on rodonca01: record 9094 of 9301
# 2
# Running data on rodried05: record 9095 of 9301
# 2
# Running data on rollida01: record 9096 of 9301
# 2
# Running data on rosalad01: record 9097 of 9301
# 1
# Running data on rossda01: record 9098 of 9301
# 1
# Running data on rossjo01: record 9099 of 9301
# 2
# Running data on rumbeni01: record 9100 of 9301
# 1
# Running data on ryanbr01: record 9101 of 9301
# 1
# Running data on sampske01: record 9102 of 9301
# 2
# Running data on schugaj01: record 9103 of 9301
# 2
# Running data on severlu01: record 9104 of 9301
# 2
# Running data on smithjo07: record 9105 of 9301
# 2
# Running data on solissa01: record 9106 of 9301
# 2
# Running data on sotogi01: record 9107 of 9301
# 1
# Running data on sucreje01: record 9108 of 9301
# 1
# Running data on suzukic01: record 9109 of 9301
# 1
# Running data on syndeno01: record 9110 of 9301
# 2
# Running data on teperry01: record 9111 of 9301
# 2
# Running data on tracyma01: record 9112 of 9301
# 1
# Running data on urenajo01: record 9113 of 9301
# 2
# Running data on valdejo03: record 9114 of 9301
# 2
# Running data on velasvi01: record 9115 of 9301
# 2
# Running data on vendipa01: record 9116 of 9301
# 3
# Running data on verrelo01: record 9117 of 9301
# 3
# Running data on wagnety01: record 9118 of 9301
# 2
# Running data on weberry01: record 9119 of 9301
# 2
# Running data on wilsoty01: record 9120 of 9301
# 2
# Running data on winklda01: record 9121 of 9301
# 2
# Running data on wislema01: record 9122 of 9301
# 2
# Running data on wojcias01: record 9123 of 9301
# 1
# Running data on wrighmi01: record 9124 of 9301
# 2
# Running data on zychto01: record 9125 of 9301
# 2
# Running data on adlemti01: record 9126 of 9301
# 1
# Running data on alcanra01: record 9127 of 9301
# 1
# Running data on altavda01: record 9128 of 9301
# 1
# Running data on anderty01: record 9129 of 9301
# 1
# Running data on antoldu01: record 9130 of 9301
# 1
# Running data on aquinja01: record 9131 of 9301
# 1
# Running data on barbajo01: record 9132 of 9301
# 1
# Running data on barneda01: record 9133 of 9301
# 1
# Running data on barneda02: record 9134 of 9301
# 1
# Running data on barneja01: record 9135 of 9301
# 1
# Running data on barneto01: record 9136 of 9301
# 1
# Running data on barreja01: record 9137 of 9301
# 1
# Running data on baumabu01: record 9138 of 9301
# 1
# Running data on berrijo01: record 9139 of 9301
# 1
# Running data on bethach01: record 9140 of 9301
# 1
# Running data on biagijo01: record 9141 of 9301
# 1
# Running data on blachty01: record 9142 of 9301
# 1
# Running data on blairaa01: record 9143 of 9301
# 1
# Running data on bleieri01: record 9144 of 9301
# 1
# Running data on boscawi01: record 9145 of 9301
# 1
# Running data on bowmama01: record 9146 of 9301
# 1
# Running data on bradlje01: record 9147 of 9301
# 1
# Running data on braulst01: record 9148 of 9301
# 1
# Running data on briceau01: record 9149 of 9301
# 1
# Running data on bridwpa01: record 9150 of 9301
# 1
# Running data on buschma01: record 9151 of 9301
# 1
# Running data on bushma01: record 9152 of 9301
# 1
# Running data on cabrema01: record 9153 of 9301
# 1
# Running data on campojo01: record 9154 of 9301
# 1
# Running data on carasma01: record 9155 of 9301
# 1
# Running data on cervehu01: record 9156 of 9301
# 2
# Running data on cessalu01: record 9157 of 9301
# 1
# Running data on chargjt01: record 9158 of 9301
# 1
# Running data on clevimi01: record 9159 of 9301
# 1
# Running data on colonjo01: record 9160 of 9301
# 1
# Running data on concege01: record 9161 of 9301
# 1
# Running data on cottojh01: record 9162 of 9301
# 1
# Running data on cuevawi01: record 9163 of 9301
# 1
# Running data on curtiza01: record 9164 of 9301
# 1
# Running data on danisty01: record 9165 of 9301
# 1
# Running data on daytogr01: record 9166 of 9301
# 1
# Running data on deanpa02: record 9167 of 9301
# 1
# Running data on delacjo01: record 9168 of 9301
# 1
# Running data on deleojo03: record 9169 of 9301
# 1
# Running data on dermoma01: record 9170 of 9301
# 1
# Running data on devench02: record 9171 of 9301
# 1
# Running data on diazda01: record 9172 of 9301
# 1
# Running data on diazed04: record 9173 of 9301
# 1
# Running data on eflinza01: record 9174 of 9301
# 1
# Running data on egeco01: record 9175 of 9301
# 2
# Running data on eschja01: record 9176 of 9301
# 1
# Running data on escobed01: record 9177 of 9301
# 1
# Running data on estevca01: record 9178 of 9301
# 1
# Running data on flahery01: record 9179 of 9301
# 1
# Running data on florody01: record 9180 of 9301
# 1
# Running data on fulmeca01: record 9181 of 9301
# 1
# Running data on fulmemi01: record 9182 of 9301
# 1
# Running data on gamboed01: record 9183 of 9301
# 1
# Running data on gantjo01: record 9184 of 9301
# 1
# Running data on garnepe01: record 9185 of 9301
# 1
# Running data on gartory01: record 9186 of 9301
# 1
# Running data on giolilu01: record 9187 of 9301
# 1
# Running data on girodch01: record 9188 of 9301
# 1
# Running data on glasnty01: record 9189 of 9301
# 1
# Running data on gloveko01: record 9190 of 9301
# 1
# Running data on goinsry01: record 9191 of 9301
# 1
# Running data on greench03: record 9192 of 9301
# 1
# Running data on gsellro01: record 9193 of 9301
# 1
# Running data on guerrta01: record 9194 of 9301
# 1
# Running data on gustaja01: record 9195 of 9301
# 1
# Running data on hartdo01: record 9196 of 9301
# 1
# Running data on hathast01: record 9197 of 9301
# 1
# Running data on hayesdr01: record 9198 of 9301
# 1
# Running data on hellebe01: record 9199 of 9301
# 1
# Running data on hoffmje02: record 9200 of 9301
# 1
# Running data on holadbr01: record 9201 of 9301
# 1
# Running data on holdejo02: record 9202 of 9301
# 1
# Running data on holtty01: record 9203 of 9301
# 1
# Running data on hoyinja01: record 9204 of 9301
# 1
# Running data on hoytja01: record 9205 of 9301
# 1
# Running data on hurshja01: record 9206 of 9301
# 1
# Running data on jenkity01: record 9207 of 9301
# 1
# Running data on kiekhde01: record 9208 of 9301
# 1
# Running data on kochma01: record 9209 of 9301
# 1
# Running data on kratzer01: record 9210 of 9301
# 2
# Running data on kuhlch01: record 9211 of 9301
# 1
# Running data on ladenty01: record 9212 of 9301
# 1
# Running data on lamarry01: record 9213 of 9301
# 1
# Running data on lawde01: record 9214 of 9301
# 1
# Running data on leclejo01: record 9215 of 9301
# 1
# Running data on lightpa01: record 9216 of 9301
# 2
# Running data on lopezre01: record 9217 of 9301
# 1
# Running data on lugose01: record 9218 of 9301
# 1
# Running data on maedake01: record 9219 of 9301
# 1
# Running data on magnida01: record 9220 of 9301
# 1
# Running data on mahlegr01: record 9221 of 9301
# 1
# Running data on manaese01: record 9222 of 9301
# 1
# Running data on mantijo01: record 9223 of 9301
# 1
# Running data on marquge01: record 9224 of 9301
# 1
# Running data on marteke02: record 9225 of 9301
# 1
# Running data on mayermi01: record 9226 of 9301
# 1
# Running data on mccarke01: record 9227 of 9301
# 1
# Running data on mejiaad01: record 9228 of 9301
# 1
# Running data on melviti01: record 9229 of 9301
# 1
# Running data on mendeyo01: record 9230 of 9301
# 1
# Running data on mengdda01: record 9231 of 9301
# 1
# Running data on merriry01: record 9232 of 9301
# 1
# Running data on millsal02: record 9233 of 9301
# 1
# Running data on minayju01: record 9234 of 9301
# 1
# Running data on miranar01: record 9235 of 9301
# 2
# Running data on molledu01: record 9236 of 9301
# 1
# Running data on montemi01: record 9237 of 9301
# 1
# Running data on morimsh01: record 9238 of 9301
# 1
# Running data on morriaj01: record 9239 of 9301
# 1
# Running data on motteta01: record 9240 of 9301
# 1
# Running data on mulleco01: record 9241 of 9301
# 1
# Running data on musgrjo01: record 9242 of 9301
# 1
# Running data on nealza01: record 9243 of 9301
# 1
# Running data on ohse01: record 9244 of 9301
# 1
# Running data on okertst01: record 9245 of 9301
# 1
# Running data on overtdi01: record 9246 of 9301
# 1
# Running data on paulida01: record 9247 of 9301
# 1
# Running data on penafe01: record 9248 of 9301
# 1
# Running data on peralwa01: record 9249 of 9301
# 1
# Running data on perdolu02: record 9250 of 9301
# 1
# Running data on phegljo01: record 9251 of 9301
# 1
# Running data on plutkad01: record 9252 of 9301
# 1
# Running data on poundbr01: record 9253 of 9301
# 1
# Running data on purkema01: record 9254 of 9301
# 1
# Running data on ramosed02: record 9255 of 9301
# 1
# Running data on reedco01: record 9256 of 9301
# 1
# Running data on reyesal02: record 9257 of 9301
# 1
# Running data on rodgebr01: record 9258 of 9301
# 1
# Running data on rodrijo04: record 9259 of 9301
# 1
# Running data on rogerta01: record 9260 of 9301
# 1
# Running data on sampsad01: record 9261 of 9301
# 1
# Running data on sardilu01: record 9262 of 9301
# 1
# Running data on saupowa01: record 9263 of 9301
# 1
# Running data on schuspa01: record 9264 of 9301
# 2
# Running data on scottro02: record 9265 of 9301
# 1
# Running data on shiplbr01: record 9266 of 9301
# 1
# Running data on shuckja01: record 9267 of 9301
# 1
# Running data on smithbl01: record 9268 of 9301
# 1
# Running data on smithja06: record 9269 of 9301
# 1
# Running data on smokejo01: record 9270 of 9301
# 1
# Running data on snellbl01: record 9271 of 9301
# 1
# Running data on somsela01: record 9272 of 9301
# 1
# Running data on stephro01: record 9273 of 9301
# 1
# Running data on stewabr01: record 9274 of 9301
# 1
# Running data on strahma01: record 9275 of 9301
# 1
# Running data on stratch01: record 9276 of 9301
# 1
# Running data on stripro01: record 9277 of 9301
# 1
# Running data on stumpda01: record 9278 of 9301
# 1
# Running data on sturdty01: record 9279 of 9301
# 1
# Running data on suareal01: record 9280 of 9301
# 1
# Running data on suterbr01: record 9281 of 9301
# 1
# Running data on taillja01: record 9282 of 9301
# 1
# Running data on tejadru01: record 9283 of 9301
# 1
# Running data on thompja03: record 9284 of 9301
# 1
# Running data on tollias01: record 9285 of 9301
# 1
# Running data on torrejo02: record 9286 of 9301
# 1
# Running data on triggan01: record 9287 of 9301
# 1
# Running data on uriasju01: record 9288 of 9301
# 1
# Running data on vargace01: record 9289 of 9301
# 1
# Running data on weavelu01: record 9290 of 9301
# 1
# Running data on wendejb01: record 9291 of 9301
# 1
# Running data on whalero01: record 9292 of 9301
# 1
# Running data on whitety01: record 9293 of 9301
# 1
# Running data on willitr01: record 9294 of 9301
# 1
# Running data on wimmeal01: record 9295 of 9301
# 1
# Running data on wittgni01: record 9296 of 9301
# 1
# Running data on wrighda04: record 9297 of 9301
# 2
# Running data on ynoaga01: record 9298 of 9301
# 1
# Running data on ynoami01: record 9299 of 9301
# 1
# Running data on youngma03: record 9300 of 9301
# 1

# %%
# JOIN WAR VALUE BASED ON PLAYER_ID
wars = "Resources/war.csv"
w_df = pd.read_csv(wars)
combined_data=pd.merge(pitching_df, w_df, how='left',on='player_id')
combined_data['WAR'].fillna(0, inplace=True)
combined_data.head()
# Out:
#          ERA HOF  Opposing_BA  completed        firstName  games    hits  \
# 0   4.500000   N     0.010000      25.00        George W.   30.0   349.0
# 1   5.566000   N     0.010000      77.00           Asahel   84.0  1107.0
# 2  11.335000   N     0.111667       4.03  Robert Vavasour   11.0   110.0
# 3   2.952857   N     0.090000     126.00  William Charles  165.0  1532.0
# 4   5.665000   N     0.010000       7.00         Frank H.    9.0   134.0
#
#    homeruns  lastName  losses  ...    player_id runs_earned  saves  seasons  \
# 0      0.05   Bechtel   20.00  ...    bechtge01       113.0   0.05      5.0
# 1      6.02  Brainard   53.00  ...    brainas01       376.0   0.05      5.0
# 2      3.04  Ferguson    3.03  ...    fergubo01        36.0   0.06      6.0
# 3     17.02    Fisher   84.00  ...    fishech01       415.0   2.05      7.0
# 4      1.03     Fleet    6.00  ...    fleetfr01        40.0   0.04      4.0
#
#    shutouts  started  strikes  walks   wins    WAR
# 0      0.05    27.00    38.01  19.01   7.01   3.57
# 1      0.05    82.00    33.01  78.01  24.01  -0.31
# 2      0.06     4.03    16.04   7.03   1.05  15.70
# 3      4.04   141.00    99.00  77.01  57.01  -2.27
# 4      0.04     8.00    27.01   6.02   2.03  -0.25
#
# [5 rows x 21 columns]

# %%
# CONVERT FINAL PITCHING DF TO CSV
# HOF COLUMN DENOTES WHETHER NOMINATED(OR INDUCTED) IN THE HALL OF FAME WITH A 'Y' OR 'N'
combined_data.to_csv('Resources/pitcher_data.csv')

# %%
combined_data.shape
# Out:
# (9301, 21)

# %%
pitching_df.head()

# %%
hof_pitchersDF = pitching_df[(pitching_df.HOF == 'Y')]
print(hof_pitchersDF.shape)
hof_pitchersDF.head()
# Out:
# (449, 20)
#           ERA HOF  Opposing_BA  completed      firstName  games    hits  \
# 87   2.855000   Y     0.131000     394.00  William Henry  403.0  3440.0
# 147  4.208333   Y     1.920000       4.03        William    9.0    55.0
# 468  4.441111   Y     0.276667     240.00     William J.  299.0  2552.0
# 526  3.721000   Y     0.252000     392.00    Amos Wilson  462.0  3384.0
# 539  6.356667   Y     0.396667       6.02     Jesse Cail   23.0   144.0
#
#      homeruns lastName  losses  outs_pitched  player_id  runs_earned  saves  \
# 87      65.02    White  166.00       10628.0  whitewi01        896.0   0.10
# 147      2.04    Ewing    3.03         141.0  ewingbu01         18.0   0.06
# 468     75.00  Gleason  131.00        7168.0  gleaski01       1007.0   6.04
# 526     76.00    Rusie  174.00       11309.0  rusieam01       1287.0   5.05
# 539      3.02  Burkett   11.01         369.0  burkeje01         76.0   0.03
#
#      seasons  shutouts  started  strikes   walks    wins
# 87      10.0     36.02   401.00  1041.00   496.0  229.01
# 147      6.0      0.06     4.03    23.02    23.0    2.05
# 468      9.0     10.05   266.00   744.00   906.0  138.00
# 526     10.0     30.01   427.00  1934.00  1704.0  245.01
# 539      3.0      0.03    12.02    84.01    94.0    3.02

# %%
len(batter_list)
# Out:
# 12716

# %%
fielders_all = pd.read_sql("SELECT * from `Batting` where playerID in %s" % str(tuple(batter_list)), connection)
fieldersDF = pd.DataFrame(fielders_all)
fieldersDF.replace('', 0.01, inplace=True)
fieldersDF.replace(0, 0.01, inplace=True)
fieldersDF.head()
# Out:
#     playerID  yearID  stint teamID lgID   G     AB      R      H     2B  ...   \
# 0  abercda01    1871      1    TRO   NA   1    4.0   0.01   0.01   0.01  ...
# 1   addybo01    1871      1    RC1   NA  25  118.0  30.00  32.00   6.00  ...
# 2  allisar01    1871      1    CL1   NA  29  137.0  28.00  40.00   4.00  ...
# 3  ansonca01    1871      1    RC1   NA  25  120.0  29.00  39.00  11.00  ...
# 4  armstbo01    1871      1    FW1   NA  12   49.0   9.00  11.00   2.00  ...
#
#      RBI    SB    CS    BB    SO   IBB   HBP    SH    SF  GIDP
# 0   0.01  0.01  0.01  0.01  0.01  0.01  0.01  0.01  0.01  0.01
# 1  13.00  8.00  1.00  4.00  0.01  0.01  0.01  0.01  0.01  0.01
# 2  19.00  3.00  1.00  2.00  5.00  0.01  0.01  0.01  0.01  0.01
# 3  16.00  6.00  2.00  2.00  1.00  0.01  0.01  0.01  0.01  0.01
# 4   5.00  0.01  1.00  0.01  1.00  0.01  0.01  0.01  0.01  0.01
#
# [5 rows x 22 columns]

# %%
batting_df = pd.DataFrame()

x = 0
for t in batter_list[:-1]:
    a = pd.read_sql("SELECT * from `Batting` where playerID='%s'"% t, connection)
    if len(a) >= 0:
        seasons = len(a)
        print('Running data on %s: record %s of %s' %(t,x, len(batter_list)-1))
        name_pull = pd.read_sql("SELECT nameLast, NameGiven from `Master` where playerID = '%s'"% t, connection)
        lastName = name_pull['nameLast'][0]
        firstName = name_pull['NameGiven'][0]
        p = fieldersDF[(fieldersDF.playerID==t)]
        games = p['G'].sum()
        ab = p['AB'].sum()
        runs = p['R'].sum()
        hits = p['H'].sum()
        _2b = p['2B'].sum()
        _3b = p['3B'].sum()
        hr = p['HR'].sum()
#         extra = _2b + _3b + hr
#         _1b = ab - extra
        bb = p['BB'].sum()
        p['IBB'] = p['IBB'].astype(str).astype(float)
        ibb = p['IBB'].sum()
        p['HBP']=p['HBP'].astype(str).astype(float)
        hbp = p['HBP'].sum()
        p['SF'] = p['SF'].astype(str).astype(float)
        sf = p['SF'].sum()
        _BA = hits / ab
        obp = (hits + bb + hbp) / (ab + bb + hbp + sf)
        slg = ((hits) + (_2b) + (_3b * 2) + (hr*3))/ab
        ops = obp + slg
        sb = p['SB'].sum()
        if t in fielders_HOF:
            hof = 'Y'
        else:
            hof = 'N'
        batting_df = batting_df.append({
            'player_id': t,
            'firstName': firstName,
            'lastName': lastName,
            'games': games,
            'runs': runs,
            'hits': hits,
#             '1B': _1b,
            '2B': _2b,
            '3B': _3b,
            'HR': hr,
#             'extra_base_hits': extra,
            'BB': bb,
            'IBB':ibb,
            'HBP':hbp,
            'SF': sf,
            'SB':sb,
            'BA': _BA,
            'OBP':obp,
            'SLG':slg,
            'OPS':ops,
            'HOF':hof,
            'seasons': seasons
        }, ignore_index=True)

        x+=1
    else:
        print('Record for %s skipped' % t)
        next
# Out:
# Running data on abercda01: record 0 of 12715
# /Users/kristopherking/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/kristopherking/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/kristopherking/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Running data on addybo01: record 1 of 12715
# Running data on allisar01: record 2 of 12715
# Running data on ansonca01: record 3 of 12715
# Running data on armstbo01: record 4 of 12715
# Running data on barkeal01: record 5 of 12715
# Running data on barrebi01: record 6 of 12715
# Running data on barrofr01: record 7 of 12715
# Running data on bassjo01: record 8 of 12715
# Running data on bealsto01: record 9 of 12715
# Running data on beaveed01: record 10 of 12715
# Running data on bellast01: record 11 of 12715
# Running data on berkena01: record 12 of 12715
# Running data on berryto01: record 13 of 12715
# Running data on berthha01: record 14 of 12715
# Running data on biermch01: record 15 of 12715
# Running data on birdge01: record 16 of 12715
# Running data on birdsda01: record 17 of 12715
# Running data on brannmi01: record 18 of 12715
# Running data on burrohe01: record 19 of 12715
# Running data on careyto01: record 20 of 12715
# Running data on carleji01: record 21 of 12715
# Running data on conefr01: record 22 of 12715
# Running data on connone01: record 23 of 12715
# Running data on cravebi01: record 24 of 12715
# Running data on cuthbne01: record 25 of 12715
# Running data on deaneha01: record 26 of 12715
# Running data on donnepe01: record 27 of 12715
# Running data on duffyed01: record 28 of 12715
# Running data on eggleda01: record 29 of 12715
# Running data on ewellge01: record 30 of 12715
# Running data on fishech01: record 31 of 12715
# Running data on fislewe01: record 32 of 12715
# Running data on flowedi01: record 33 of 12715
# Running data on flynncl01: record 34 of 12715
# Running data on foleyto01: record 35 of 12715
# Running data on foranji01: record 36 of 12715
# Running data on fulmech01: record 37 of 12715
# Running data on glennjo01: record 38 of 12715
# Running data on goldswa01: record 39 of 12715
# Running data on hallge01: record 40 of 12715
# Running data on halliji01: record 41 of 12715
# Running data on hamra01: record 42 of 12715
# Running data on hastisc01: record 43 of 12715
# Running data on heubege01: record 44 of 12715
# Running data on highadi01: record 45 of 12715
# Running data on hodesch01: record 46 of 12715
# Running data on jackssa01: record 47 of 12715
# Running data on johnsca01: record 48 of 12715
# Running data on kellybi01: record 49 of 12715
# Running data on kimbage01: record 50 of 12715
# Running data on kingma01: record 51 of 12715
# Running data on kingst01: record 52 of 12715
# Running data on kohlehe01: record 53 of 12715
# Running data on lennobi01: record 54 of 12715
# Running data on leonaan01: record 55 of 12715
# Running data on malonfe01: record 56 of 12715
# Running data on mcatebu01: record 57 of 12715
# Running data on mcderjo01: record 58 of 12715
# Running data on mcgeami01: record 59 of 12715
# Running data on mcveyca01: record 60 of 12715
# Running data on millsch01: record 61 of 12715
# Running data on millsev01: record 62 of 12715
# Running data on minched01: record 63 of 12715
# Running data on nortofr01: record 64 of 12715
# Running data on patteda01: record 65 of 12715
# Running data on phelpne01: record 66 of 12715
# Running data on pikeli01: record 67 of 12715
# Running data on prattal01: record 68 of 12715
# Running data on prattto01: record 69 of 12715
# Running data on questjo01: record 70 of 12715
# Running data on quinnpa02: record 71 of 12715
# Running data on radcljo01: record 72 of 12715
# Running data on reachal01: record 73 of 12715
# Running data on sagerpo01: record 74 of 12715
# Running data on schafha01: record 75 of 12715
# Running data on senseco01: record 76 of 12715
# Running data on simmojo01: record 77 of 12715
# Running data on smithch01: record 78 of 12715
# Running data on startjo01: record 79 of 12715
# Running data on stirega01: record 80 of 12715
# Running data on sweasch01: record 81 of 12715
# Running data on treacfr01: record 82 of 12715
# Running data on waterfr01: record 83 of 12715
# Running data on whiteel01: record 84 of 12715
# Running data on whitewa01: record 85 of 12715
# Running data on woodji01: record 86 of 12715
# Running data on wrighha01: record 87 of 12715
# Running data on yorkto01: record 88 of 12715
# Running data on allenha01: record 89 of 12715
# Running data on allisan01: record 90 of 12715
# Running data on allisbi01: record 91 of 12715
# Running data on arnolbi01: record 92 of 12715
# Running data on barloto01: record 93 of 12715
# Running data on barre01: record 94 of 12715
# Running data on besti01: record 95 of 12715
# Running data on bielaos01: record 96 of 12715
# Running data on boydbi01: record 97 of 12715
# Running data on brownol01: record 98 of 12715
# Running data on burdoja01: record 99 of 12715
# Running data on clappjo01: record 100 of 12715
# Running data on clarede01: record 101 of 12715
# Running data on coughde01: record 102 of 12715
# Running data on dehlmhe01: record 103 of 12715
# Running data on doschhe01: record 104 of 12715
# Running data on doylejo01: record 105 of 12715
# Running data on fieldge01: record 106 of 12715
# Running data on fletcge01: record 107 of 12715
# Running data on galvijo01: record 108 of 12715
# Running data on hallji01: record 109 of 12715
# Running data on hicksna01: record 110 of 12715
# Running data on higby01: record 111 of 12715
# Running data on holdsji01: record 112 of 12715
# Running data on holliho01: record 113 of 12715
# Running data on huntdi01: record 114 of 12715
# Running data on hurledi01: record 115 of 12715
# Running data on jewetna01: record 116 of 12715
# Running data on kavan01: record 117 of 12715
# Running data on kennejo01: record 118 of 12715
# Running data on leutz01: record 119 of 12715
# Running data on lowech01: record 120 of 12715
# Running data on martial01: record 121 of 12715
# Running data on mccarfr01: record 122 of 12715
# Running data on mcdonja01: record 123 of 12715
# Running data on millejo01: record 124 of 12715
# Running data on mulle01: record 125 of 12715
# Running data on murnati01: record 126 of 12715
# Running data on nelsoca01: record 127 of 12715
# Running data on orourji01: record 128 of 12715
# Running data on reachbo01: record 129 of 12715
# Running data on remseja01: record 130 of 12715
# Running data on robinva01: record 131 of 12715
# Running data on rogerfr01: record 132 of 12715
# Running data on snydeji01: record 133 of 12715
# Running data on snydejo01: record 134 of 12715
# Running data on spenc01: record 135 of 12715
# Running data on studlse01: record 136 of 12715
# Running data on swandma01: record 137 of 12715
# Running data on thakeal01: record 138 of 12715
# Running data on tippeji01: record 139 of 12715
# Running data on worthhe01: record 140 of 12715
# Running data on yeatmbi01: record 141 of 12715
# Running data on atkined01: record 142 of 12715
# Running data on austihe01: record 143 of 12715
# Running data on campbmi02: record 144 of 12715
# Running data on cranefr01: record 145 of 12715
# Running data on donnejo01: record 146 of 12715
# Running data on eland01: record 147 of 12715
# Running data on farrojo01: record 148 of 12715
# Running data on gerhajo01: record 149 of 12715
# Running data on hoopemi01: record 150 of 12715
# Running data on johnsto01: record 151 of 12715
# Running data on jones01: record 152 of 12715
# Running data on kernajo01: record 153 of 12715
# Running data on kesslhe01: record 154 of 12715
# Running data on laughbe01: record 155 of 12715
# Running data on mannija01: record 156 of 12715
# Running data on nevinal01: record 157 of 12715
# Running data on popplge01: record 158 of 12715
# Running data on saylo01: record 159 of 12715
# Running data on sheppjo01: record 160 of 12715
# Running data on simpsma01: record 161 of 12715
# Running data on smithbi01: record 162 of 12715
# Running data on smithjo01: record 163 of 12715
# Running data on snydepo01: record 164 of 12715
# Running data on wallho01: record 165 of 12715
# Running data on woodhre01: record 166 of 12715
# Running data on wordsfa01: record 167 of 12715
# Running data on barnibi01: record 168 of 12715
# Running data on boardfr01: record 169 of 12715
# Running data on bradyst01: record 170 of 12715
# Running data on brown01: record 171 of 12715
# Running data on carlle01: record 172 of 12715
# Running data on chapmja01: record 173 of 12715
# Running data on collida01: record 174 of 12715
# Running data on connete01: record 175 of 12715
# Running data on farreja01: record 176 of 12715
# Running data on gaver01: record 177 of 12715
# Running data on gilro01: record 178 of 12715
# Running data on knowdja01: record 179 of 12715
# Running data on ledwimi01: record 180 of 12715
# Running data on mcgeepa01: record 181 of 12715
# Running data on mckenfr01: record 182 of 12715
# Running data on milleto01: record 183 of 12715
# Running data on oneal01: record 184 of 12715
# Running data on quinl01: record 185 of 12715
# Running data on reedhu01: record 186 of 12715
# Running data on revilhe01: record 187 of 12715
# Running data on shaffor01: record 188 of 12715
# Running data on smilebi01: record 189 of 12715
# Running data on snowch01: record 190 of 12715
# Running data on tayloza01: record 191 of 12715
# Running data on westbi01: record 192 of 12715
# Running data on wood01: record 193 of 12715
# Running data on abadijo01: record 194 of 12715
# Running data on banckst01: record 195 of 12715
# Running data on bolan01: record 196 of 12715
# Running data on booth01: record 197 of 12715
# Running data on bradlge01: record 198 of 12715
# Running data on brady01: record 199 of 12715
# Running data on bushodo01: record 200 of 12715
# Running data on carbijo01: record 201 of 12715
# Running data on coonwi01: record 202 of 12715
# Running data on croftar01: record 203 of 12715
# Running data on crowlbi01: record 204 of 12715
# Running data on dailejo01: record 205 of 12715
# Running data on dillojo01: record 206 of 12715
# Running data on dillopa01: record 207 of 12715
# Running data on dolele01: record 208 of 12715
# Running data on ellicjo01: record 209 of 12715
# Running data on evans01: record 210 of 12715
# Running data on fieldsa01: record 211 of 12715
# Running data on flintsi01: record 212 of 12715
# Running data on foleywi01: record 213 of 12715
# Running data on fulmewa01: record 214 of 12715
# Running data on gilgahu01: record 215 of 12715
# Running data on gilmoji01: record 216 of 12715
# Running data on goldsfr01: record 217 of 12715
# Running data on haguebi01: record 218 of 12715
# Running data on harbibi01: record 219 of 12715
# Running data on harriri01: record 220 of 12715
# Running data on hautzch01: record 221 of 12715
# Running data on helli01: record 222 of 12715
# Running data on keenaji01: record 223 of 12715
# Running data on keerlge01: record 224 of 12715
# Running data on knighlo01: record 225 of 12715
# Running data on lathaju01: record 226 of 12715
# Running data on lowryjo01: record 227 of 12715
# Running data on masonch01: record 228 of 12715
# Running data on mcclobi01: record 229 of 12715
# Running data on mcginti01: record 230 of 12715
# Running data on mckeljo01: record 231 of 12715
# Running data on metcaal01: record 232 of 12715
# Running data on mooremo01: record 233 of 12715
# Running data on munnho01: record 234 of 12715
# Running data on nichoal01: record 235 of 12715
# Running data on oneilj01: record 236 of 12715
# Running data on oranto01: record 237 of 12715
# Running data on quinnpa01: record 238 of 12715
# Running data on redmobi01: record 239 of 12715
# Running data on resslla01: record 240 of 12715
# Running data on rextewi01: record 241 of 12715
# Running data on richmjo01: record 242 of 12715
# Running data on rileybi01: record 243 of 12715
# Running data on rocapad01: record 244 of 12715
# Running data on sewarge01: record 245 of 12715
# Running data on shaff01: record 246 of 12715
# Running data on sheri01: record 247 of 12715
# Running data on smithto01: record 248 of 12715
# Running data on somered01: record 249 of 12715
# Running data on stevero01: record 250 of 12715
# Running data on stodd01: record 251 of 12715
# Running data on sulli01: record 252 of 12715
# Running data on terry01: record 253 of 12715
# Running data on thompan01: record 254 of 12715
# Running data on thompfr01: record 255 of 12715
# Running data on trenwge01: record 256 of 12715
# Running data on waittch01: record 257 of 12715
# Running data on walkeos01: record 258 of 12715
# Running data on warnefr01: record 259 of 12715
# Running data on withech01: record 260 of 12715
# Running data on wrighsa01: record 261 of 12715
# Running data on berghjo01: record 262 of 12715
# Running data on bradlfo01: record 263 of 12715
# Running data on currepe01: record 264 of 12715
# Running data on fairge01: record 265 of 12715
# Running data on fousebi01: record 266 of 12715
# Running data on hayesmi01: record 267 of 12715
# Running data on holbebi01: record 268 of 12715
# Running data on larkite01: record 269 of 12715
# Running data on malonjo01: record 270 of 12715
# Running data on mcguijo01: record 271 of 12715
# Running data on mullejo01: record 272 of 12715
# Running data on paullo01: record 273 of 12715
# Running data on piersda01: record 274 of 12715
# Running data on rittewh01: record 275 of 12715
# Running data on shandji01: record 276 of 12715
# Running data on snydere01: record 277 of 12715
# Running data on treacpe01: record 278 of 12715
# Running data on valenbo01: record 279 of 12715
# Running data on wardji01: record 280 of 12715
# Running data on whitnfr01: record 281 of 12715
# Running data on buncejo01: record 282 of 12715
# Running data on edench01: record 283 of 12715
# Running data on gleasja01: record 284 of 12715
# Running data on haldejo01: record 285 of 12715
# Running data on leele01: record 286 of 12715
# Running data on littlha01: record 287 of 12715
# Running data on loftuto01: record 288 of 12715
# Running data on mckenpa01: record 289 of 12715
# Running data on millege01: record 290 of 12715
# Running data on newelte01: record 291 of 12715
# Running data on pikeja01: record 292 of 12715
# Running data on roweda01: record 293 of 12715
# Running data on smithha01: record 294 of 12715
# Running data on sullich01: record 295 of 12715
# Running data on tayloli01: record 296 of 12715
# Running data on bennech01: record 297 of 12715
# Running data on blissfr01: record 298 of 12715
# Running data on creamge01: record 299 of 12715
# Running data on dalryab01: record 300 of 12715
# Running data on dickebu01: record 301 of 12715
# Running data on goodmja01: record 302 of 12715
# Running data on healeto01: record 303 of 12715
# Running data on jennial01: record 304 of 12715
# Running data on mcclebi01: record 305 of 12715
# Running data on mckelru01: record 306 of 12715
# Running data on powerph01: record 307 of 12715
# Running data on sullibi01: record 308 of 12715
# Running data on traffbi01: record 309 of 12715
# Running data on wheelha01: record 310 of 12715
# Running data on adamsge01: record 311 of 12715
# Running data on allenja01: record 312 of 12715
# Running data on burkemi01: record 313 of 12715
# Running data on carpehi01: record 314 of 12715
# Running data on caskied01: record 315 of 12715
# Running data on clappaa01: record 316 of 12715
# Running data on cogswed01: record 317 of 12715
# Running data on deckefr01: record 318 of 12715
# Running data on evansja01: record 319 of 12715
# Running data on farreja02: record 320 of 12715
# Running data on gardngi01: record 321 of 12715
# Running data on gilliba01: record 322 of 12715
# Running data on gorege01: record 323 of 12715
# Running data on grossem01: record 324 of 12715
# Running data on gunklfr01: record 325 of 12715
# Running data on hallal01: record 326 of 12715
# Running data on hawesbi01: record 327 of 12715
# Running data on hawketh01: record 328 of 12715
# Running data on hoffmhi01: record 329 of 12715
# Running data on hotalpe01: record 330 of 12715
# Running data on houcksa01: record 331 of 12715
# Running data on kellyjo01: record 332 of 12715
# Running data on kellyki02: record 333 of 12715
# Running data on kemmlru01: record 334 of 12715
# Running data on kennedo01: record 335 of 12715
# Running data on libbyst01: record 336 of 12715
# Running data on magnejo01: record 337 of 12715
# Running data on mansemi01: record 338 of 12715
# Running data on mccorha01: record 339 of 12715
# Running data on mcmanpa01: record 340 of 12715
# Running data on olearda01: record 341 of 12715
# Running data on orourjo01: record 342 of 12715
# Running data on osterch01: record 343 of 12715
# Running data on phillbi01: record 344 of 12715
# Running data on reillch01: record 345 of 12715
# Running data on richmle01: record 346 of 12715
# Running data on roweja01: record 347 of 12715
# Running data on shoupjo01: record 348 of 12715
# Running data on stedrjo01: record 349 of 12715
# Running data on stockle01: record 350 of 12715
# Running data on striege01: record 351 of 12715
# Running data on sullide01: record 352 of 12715
# Running data on whitebi01: record 353 of 12715
# Running data on ahearch01: record 354 of 12715
# Running data on briodfa01: record 355 of 12715
# Running data on connoro01: record 356 of 12715
# Running data on cranesa01: record 357 of 12715
# Running data on dignast01: record 358 of 12715
# Running data on dorgaje01: record 359 of 12715
# Running data on dunlafr01: record 360 of 12715
# Running data on esterdu01: record 361 of 12715
# Running data on gillepe01: record 362 of 12715
# Running data on haleyfr01: record 363 of 12715
# Running data on hanlone01: record 364 of 12715
# Running data on kearnto01: record 365 of 12715
# Running data on lathaar01: record 366 of 12715
# Running data on lawlomi01: record 367 of 12715
# Running data on mountfr01: record 368 of 12715
# Running data on moynami01: record 369 of 12715
# Running data on radboch01: record 370 of 12715
# Running data on reilljo01: record 371 of 12715
# Running data on sommejo01: record 372 of 12715
# Running data on stearec01: record 373 of 12715
# Running data on straujo01: record 374 of 12715
# Running data on tobinbi01: record 375 of 12715
# Running data on trottsa01: record 376 of 12715
# Running data on whitnar01: record 377 of 12715
# Running data on woodge01: record 378 of 12715
# Running data on deaslpa01: record 379 of 12715
# Running data on derbyge01: record 380 of 12715
# Running data on flahema01: record 381 of 12715
# Running data on lewisfr01: record 382 of 12715
# Running data on morrijo02: record 383 of 12715
# Running data on myershe01: record 384 of 12715
# Running data on nicolhu01: record 385 of 12715
# Running data on piercan01: record 386 of 12715
# Running data on powelma01: record 387 of 12715
# Running data on quinnjo01: record 388 of 12715
# Running data on stratas01: record 389 of 12715
# Running data on swarted01: record 390 of 12715
# Running data on troyda01: record 391 of 12715
# Running data on wisesa01: record 392 of 12715
# Running data on arundtu01: record 393 of 12715
# Running data on birchju01: record 394 of 12715
# Running data on blakibo01: record 395 of 12715
# Running data on browned01: record 396 of 12715
# Running data on brownto01: record 397 of 12715
# Running data on burkeja01: record 398 of 12715
# Running data on burtfr01: record 399 of 12715
# Running data on carrocl01: record 400 of 12715
# Running data on caseybo01: record 401 of 12715
# Running data on clinemo01: record 402 of 12715
# Running data on critcmo01: record 403 of 12715
# Running data on crottjo01: record 404 of 12715
# Running data on dorrbe01: record 405 of 12715
# Running data on dwyerjo01: record 406 of 12715
# Running data on dylerjo01: record 407 of 12715
# Running data on eastha01: record 408 of 12715
# Running data on eversto01: record 409 of 12715
# Running data on farrebi01: record 410 of 12715
# Running data on farrejo01: record 411 of 12715
# Running data on forstto01: record 412 of 12715
# Running data on geisbi01: record 413 of 12715
# Running data on gleasbi01: record 414 of 12715
# Running data on greenbi01: record 415 of 12715
# Running data on halpiji01: record 416 of 12715
# Running data on hayesja01: record 417 of 12715
# Running data on hoganed01: record 418 of 12715
# Running data on housech02: record 419 of 12715
# Running data on irwinjo01: record 420 of 12715
# Running data on jacobha01: record 421 of 12715
# Running data on jonesbi01: record 422 of 12715
# Running data on kienzbi01: record 423 of 12715
# Running data on kinziwa01: record 424 of 12715
# Running data on lanech01: record 425 of 12715
# Running data on mannfr01: record 426 of 12715
# Running data on manniti01: record 427 of 12715
# Running data on mansejo01: record 428 of 12715
# Running data on maskrha01: record 429 of 12715
# Running data on maskrle01: record 430 of 12715
# Running data on mccafha01: record 431 of 12715
# Running data on mccluha01: record 432 of 12715
# Running data on mclaufr01: record 433 of 12715
# Running data on mcphebi01: record 434 of 12715
# Running data on merried01: record 435 of 12715
# Running data on morgabi02: record 436 of 12715
# Running data on morrito01: record 437 of 12715
# Running data on muldomi01: record 438 of 12715
# Running data on navasa01: record 439 of 12715
# Running data on obrieja01: record 440 of 12715
# Running data on pfefffr01: record 441 of 12715
# Running data on piercgr01: record 442 of 12715
# Running data on recciph01: record 443 of 12715
# Running data on robinya01: record 444 of 12715
# Running data on rowened01: record 445 of 12715
# Running data on sayji01: record 446 of 12715
# Running data on scharni01: record 447 of 12715
# Running data on scottmi01: record 448 of 12715
# Running data on shetzjo01: record 449 of 12715
# Running data on smithjo02: record 450 of 12715
# Running data on smithl01: record 451 of 12715
# Running data on striccu01: record 452 of 12715
# Running data on stricjo01: record 453 of 12715
# Running data on sullida01: record 454 of 12715
# Running data on sweench01: record 455 of 12715
# Running data on thomptu01: record 456 of 12715
# Running data on tiernbi01: record 457 of 12715
# Running data on tillejo01: record 458 of 12715
# Running data on whitied01: record 459 of 12715
# Running data on williju01: record 460 of 12715
# Running data on wolfji01: record 461 of 12715
# Running data on wyliere01: record 462 of 12715
# Running data on bakelje01: record 463 of 12715
# Running data on bakerge01: record 464 of 12715
# Running data on bakerph01: record 465 of 12715
# Running data on benedar01: record 466 of 12715
# Running data on bloggwe01: record 467 of 12715
# Running data on brougca01: record 468 of 12715
# Running data on cadych01: record 469 of 12715
# Running data on childsa01: record 470 of 12715
# Running data on corkhpo01: record 471 of 12715
# Running data on cramedi01: record 472 of 12715
# Running data on darlide01: record 473 of 12715
# Running data on devinji01: record 474 of 12715
# Running data on doyleco01: record 475 of 12715
# Running data on emslibo01: record 476 of 12715
# Running data on farrasi01: record 477 of 12715
# Running data on friespe01: record 478 of 12715
# Running data on gladmbu01: record 479 of 12715
# Running data on guinebe01: record 480 of 12715
# Running data on hackeme01: record 481 of 12715
# Running data on hendeha01: record 482 of 12715
# Running data on hinesmi01: record 483 of 12715
# Running data on hubbaal01: record 484 of 12715
# Running data on humphjo01: record 485 of 12715
# Running data on ingrach01: record 486 of 12715
# Running data on jonesja01: record 487 of 12715
# Running data on kellych01: record 488 of 12715
# Running data on kenneed01: record 489 of 12715
# Running data on kuehnbi01: record 490 of 12715
# Running data on lough01: record 491 of 12715
# Running data on mcintfr01: record 492 of 12715
# Running data on mclauto01: record 493 of 12715
# Running data on mulvejo01: record 494 of 12715
# Running data on oldfida01: record 495 of 12715
# Running data on orrda01: record 496 of 12715
# Running data on pirieji01: record 497 of 12715
# Running data on princwa01: record 498 of 12715
# Running data on radfopa01: record 499 of 12715
# Running data on reidbi01: record 500 of 12715
# Running data on reipsch01: record 501 of 12715
# Running data on ringofr01: record 502 of 12715
# Running data on schwabi01: record 503 of 12715
# Running data on smithed01: record 504 of 12715
# Running data on smithed02: record 505 of 12715
# Running data on suckto01: record 506 of 12715
# Running data on sweenro01: record 507 of 12715
# Running data on wardpi01: record 508 of 12715
# Running data on weihepo01: record 509 of 12715
# Running data on winklge01: record 510 of 12715
# Running data on wolstab01: record 511 of 12715
# Running data on akejo01: record 512 of 12715
# Running data on albergu01: record 513 of 12715
# Running data on alexani01: record 514 of 12715
# Running data on allenhe01: record 515 of 12715
# Running data on andreed01: record 516 of 12715
# Running data on andrewa01: record 517 of 12715
# Running data on annisbi01: record 518 of 12715
# Running data on ardnejo01: record 519 of 12715
# Running data on aydelja01: record 520 of 12715
# Running data on bahrefr01: record 521 of 12715
# Running data on bakerch01: record 522 of 12715
# Running data on baldwla01: record 523 of 12715
# Running data on barbech01: record 524 of 12715
# Running data on barklsa01: record 525 of 12715
# Running data on barnebi01: record 526 of 12715
# Running data on barrema01: record 527 of 12715
# Running data on bassech01: record 528 of 12715
# Running data on baueral01: record 529 of 12715
# Running data on beachja01: record 530 of 12715
# Running data on beatlda01: record 531 of 12715
# Running data on beckfr01: record 532 of 12715
# Running data on behelst01: record 533 of 12715
# Running data on benneik01: record 534 of 12715
# Running data on berkefr01: record 535 of 12715
# Running data on berrych01: record 536 of 12715
# Running data on bignege01: record 537 of 12715
# Running data on bishofr01: record 538 of 12715
# Running data on blaisdi01: record 539 of 12715
# Running data on bradlal01: record 540 of 12715
# Running data on brennji01: record 541 of 12715
# Running data on briggch01: record 542 of 12715
# Running data on brownji01: record 543 of 12715
# Running data on bukerha01: record 544 of 12715
# Running data on bullasi01: record 545 of 12715
# Running data on burcher01: record 546 of 12715
# Running data on burnspa01: record 547 of 12715
# Running data on butlebi01: record 548 of 12715
# Running data on butleki01: record 549 of 12715
# Running data on callaed01: record 550 of 12715
# Running data on callapa01: record 551 of 12715
# Running data on carroch01: record 552 of 12715
# Running data on carrofr01: record 553 of 12715
# Running data on carropa01: record 554 of 12715
# Running data on carrosc01: record 555 of 12715
# Running data on caseyda01: record 556 of 12715
# Running data on caseyde01: record 557 of 12715
# Running data on chattji01: record 558 of 12715
# Running data on clemeja01: record 559 of 12715
# Running data on cleveel01: record 560 of 12715
# Running data on colgaed01: record 561 of 12715
# Running data on collich01: record 562 of 12715
# Running data on connojo01: record 563 of 12715
# Running data on conwabi01: record 564 of 12715
# Running data on cookpa01: record 565 of 12715
# Running data on corcomi01: record 566 of 12715
# Running data on corriph01: record 567 of 12715
# Running data on coxfr01: record 568 of 12715
# Running data on creegma01: record 569 of 12715
# Running data on cronida01: record 570 of 12715
# Running data on crosscl01: record 571 of 12715
# Running data on crowljo01: record 572 of 12715
# Running data on cuffjo01: record 573 of 12715
# Running data on cullejo01: record 574 of 12715
# Running data on cusicto01: record 575 of 12715
# Running data on daisege01: record 576 of 12715
# Running data on dalyto01: record 577 of 12715
# Running data on davisda01: record 578 of 12715
# Running data on davisju01: record 579 of 12715
# Running data on dealypa01: record 580 of 12715
# Running data on deasljo01: record 581 of 12715
# Running data on deckeha01: record 582 of 12715
# Running data on deeji01: record 583 of 12715
# Running data on depanmi01: record 584 of 12715
# Running data on donneji01: record 585 of 12715
# Running data on donneji02: record 586 of 12715
# Running data on doughch01: record 587 of 12715
# Running data on dowcl01: record 588 of 12715
# Running data on drakely01: record 589 of 12715
# Running data on duganbi01: record 590 of 12715
# Running data on dunnst01: record 591 of 12715
# Running data on dwighal01: record 592 of 12715
# Running data on eastehe01: record 593 of 12715
# Running data on faatzja01: record 594 of 12715
# Running data on falchan01: record 595 of 12715
# Running data on farleto01: record 596 of 12715
# Running data on fennefr01: record 597 of 12715
# Running data on firthte01: record 598 of 12715
# Running data on fishech02: record 599 of 12715
# Running data on fishege01: record 600 of 12715
# Running data on flynnjo01: record 601 of 12715
# Running data on forded01: record 602 of 12715
# Running data on fostero02: record 603 of 12715
# Running data on frank01: record 604 of 12715
# Running data on gagusch01: record 605 of 12715
# Running data on ganzech01: record 606 of 12715
# Running data on gardnal01: record 607 of 12715
# Running data on gastfed01: record 608 of 12715
# Running data on gilleto01: record 609 of 12715
# Running data on gilmapi01: record 610 of 12715
# Running data on glenned01: record 611 of 12715
# Running data on goldswa02: record 612 of 12715
# Running data on gormato04: record 613 of 12715
# Running data on gradyjo01: record 614 of 12715
# Running data on grahabe01: record 615 of 12715
# Running data on grayji01: record 616 of 12715
# Running data on greenji01: record 617 of 12715
# Running data on griffsa01: record 618 of 12715
# Running data on griffth01: record 619 of 12715
# Running data on gunnito01: record 620 of 12715
# Running data on gunsojo01: record 621 of 12715
# Running data on hackewa01: record 622 of 12715
# Running data on hannajo01: record 623 of 12715
# Running data on hardilo01: record 624 of 12715
# Running data on harrifr01: record 625 of 12715
# Running data on henglmo01: record 626 of 12715
# Running data on hibbajo01: record 627 of 12715
# Running data on hoganed02: record 628 of 12715
# Running data on hoovebu01: record 629 of 12715
# Running data on housech01: record 630 of 12715
# Running data on huntebi01: record 631 of 12715
# Running data on johnsbi01: record 632 of 12715
# Running data on johnsdi01: record 633 of 12715
# Running data on jones02: record 634 of 12715
# Running data on jonesch02: record 635 of 12715
# Running data on jonesfr01: record 636 of 12715
# Running data on joneshe01: record 637 of 12715
# Running data on joypo01: record 638 of 12715
# Running data on kalbfch01: record 639 of 12715
# Running data on kappejo01: record 640 of 12715
# Running data on kenneed02: record 641 of 12715
# Running data on kerinjo01: record 642 of 12715
# Running data on kimbesa01: record 643 of 12715
# Running data on kingsa01: record 644 of 12715
# Running data on knighjo01: record 645 of 12715
# Running data on knowlji01: record 646 of 12715
# Running data on koonsha01: record 647 of 12715
# Running data on krehmch01: record 648 of 12715
# Running data on kriegbi01: record 649 of 12715
# Running data on larki01: record 650 of 12715
# Running data on larkihe01: record 651 of 12715
# Running data on lavinjo01: record 652 of 12715
# Running data on lehanja01: record 653 of 12715
# Running data on levisch01: record 654 of 12715
# Running data on lockema01: record 655 of 12715
# Running data on loughbi01: record 656 of 12715
# Running data on lowedi01: record 657 of 12715
# Running data on lynchto01: record 658 of 12715
# Running data on macarma01: record 659 of 12715
# Running data on manloch01: record 660 of 12715
# Running data on manniji01: record 661 of 12715
# Running data on matthst01: record 662 of 12715
# Running data on mccarto01: record 663 of 12715
# Running data on mccauji01: record 664 of 12715
# Running data on mcdonji01: record 665 of 12715
# Running data on mcfarch01: record 666 of 12715
# Running data on mcgarch01: record 667 of 12715
# Running data on mckeefr01: record 668 of 12715
# Running data on mckeeji01: record 669 of 12715
# Running data on mckened01: record 670 of 12715
# Running data on mckinal01: record 671 of 12715
# Running data on mclauja01: record 672 of 12715
# Running data on mcquemo01: record 673 of 12715
# Running data on mcrem01: record 674 of 12715
# Running data on meinkfr01: record 675 of 12715
# Running data on meistge01: record 676 of 12715
# Running data on meyerlo01: record 677 of 12715
# Running data on milledo01: record 678 of 12715
# Running data on milleed01: record 679 of 12715
# Running data on millejo02: record 680 of 12715
# Running data on millijo01: record 681 of 12715
# Running data on moffejo01: record 682 of 12715
# Running data on monrofr01: record 683 of 12715
# Running data on mooreha01: record 684 of 12715
# Running data on mooreje01: record 685 of 12715
# Running data on morgabi01: record 686 of 12715
# Running data on morrie01: record 687 of 12715
# Running data on morrijo03: record 688 of 12715
# Running data on morrip01: record 689 of 12715
# Running data on mullihe01: record 690 of 12715
# Running data on mullijo01: record 691 of 12715
# Running data on muncejo01: record 692 of 12715
# Running data on mundige01: record 693 of 12715
# Running data on murph01: record 694 of 12715
# Running data on murphjo01: record 695 of 12715
# Running data on murphto01: record 696 of 12715
# Running data on murphwi01: record 697 of 12715
# Running data on murrami01: record 698 of 12715
# Running data on myersal01: record 699 of 12715
# Running data on myersge01: record 700 of 12715
# Running data on nelsobi01: record 701 of 12715
# Running data on noftsge01: record 702 of 12715
# Running data on nuszem01: record 703 of 12715
# Running data on obriejo01: record 704 of 12715
# Running data on odonnjo01: record 705 of 12715
# Running data on olinfr01: record 706 of 12715
# Running data on oxleyhe01: record 707 of 12715
# Running data on pattige01: record 708 of 12715
# Running data on peakel01: record 709 of 12715
# Running data on peltzjo01: record 710 of 12715
# Running data on pheladi01: record 711 of 12715
# Running data on phillma01: record 712 of 12715
# Running data on piercma01: record 713 of 12715
# Running data on portehe01: record 714 of 12715
# Running data on portema01: record 715 of 12715
# Running data on powelji01: record 716 of 12715
# Running data on quinnjo02: record 717 of 12715
# Running data on quintma01: record 718 of 12715
# Running data on reedeic01: record 719 of 12715
# Running data on reisich01: record 720 of 12715
# Running data on richa01: record 721 of 12715
# Running data on ricklch01: record 722 of 12715
# Running data on robinch01: record 723 of 12715
# Running data on robinfr01: record 724 of 12715
# Running data on rollibi01: record 725 of 12715
# Running data on roxbuji01: record 726 of 12715
# Running data on ruddejo01: record 727 of 12715
# Running data on ryanjo03: record 728 of 12715
# Running data on ryderto01: record 729 of 12715
# Running data on santred01: record 730 of 12715
# Running data on scanlpa01: record 731 of 12715
# Running data on scott01: record 732 of 12715
# Running data on seradbi01: record 733 of 12715
# Running data on sextoto01: record 734 of 12715
# Running data on shaffta01: record 735 of 12715
# Running data on siegejo01: record 736 of 12715
# Running data on siffefr01: record 737 of 12715
# Running data on sixsmed01: record 738 of 12715
# Running data on skinnal01: record 739 of 12715
# Running data on sladear01: record 740 of 12715
# Running data on slattmi01: record 741 of 12715
# Running data on smithbi02: record 742 of 12715
# Running data on smithfr01: record 743 of 12715
# Running data on smithph01: record 744 of 12715
# Running data on sneedjo01: record 745 of 12715
# Running data on stanljo01: record 746 of 12715
# Running data on struval01: record 747 of 12715
# Running data on sullipa01: record 748 of 12715
# Running data on sullite01: record 749 of 12715
# Running data on sutclsy01: record 750 of 12715
# Running data on swanan01: record 751 of 12715
# Running data on sweenje01: record 752 of 12715
# Running data on tennefr01: record 753 of 12715
# Running data on thompar01: record 754 of 12715
# Running data on trayji01: record 755 of 12715
# Running data on turbije01: record 756 of 12715
# Running data on vadebge01: record 757 of 12715
# Running data on vintobi01: record 758 of 12715
# Running data on walkefl01: record 759 of 12715
# Running data on walkewa01: record 760 of 12715
# Running data on walkewe01: record 761 of 12715
# Running data on wardjo02: record 762 of 12715
# Running data on watkibi01: record 763 of 12715
# Running data on weberha01: record 764 of 12715
# Running data on weberjo01: record 765 of 12715
# Running data on werdepe01: record 766 of 12715
# Running data on werrijo01: record 767 of 12715
# Running data on westbu01: record 768 of 12715
# Running data on whitegu01: record 769 of 12715
# Running data on wiley01: record 770 of 12715
# Running data on wills01: record 771 of 12715
# Running data on wilsotu01: record 772 of 12715
# Running data on woodfr01: record 773 of 12715
# Running data on woulfji01: record 774 of 12715
# Running data on yeweled01: record 775 of 12715
# Running data on zimmech01: record 776 of 12715
# Running data on alvorbi01: record 777 of 12715
# Running data on andruwi01: record 778 of 12715
# Running data on bellfr01: record 779 of 12715
# Running data on bryange01: record 780 of 12715
# Running data on collvbi01: record 781 of 12715
# Running data on crossam01: record 782 of 12715
# Running data on dailyco01: record 783 of 12715
# Running data on derbyge02: record 784 of 12715
# Running data on driscde02: record 785 of 12715
# Running data on drissmi01: record 786 of 12715
# Running data on fogarjo01: record 787 of 12715
# Running data on greered01: record 788 of 12715
# Running data on hatfigi01: record 789 of 12715
# Running data on hilanjo01: record 790 of 12715
# Running data on jones03: record 791 of 12715
# Running data on kellona01: record 792 of 12715
# Running data on knoufed01: record 793 of 12715
# Running data on lyonsde01: record 794 of 12715
# Running data on mackre01: record 795 of 12715
# Running data on mappege01: record 796 of 12715
# Running data on mccaf01: record 797 of 12715
# Running data on mcdersa01: record 798 of 12715
# Running data on mctamji01: record 799 of 12715
# Running data on mcveyge01: record 800 of 12715
# Running data on pechige01: record 801 of 12715
# Running data on piersdi01: record 802 of 12715
# Running data on reilljo02: record 803 of 12715
# Running data on rittech01: record 804 of 12715
# Running data on sewared01: record 805 of 12715
# Running data on stapljo01: record 806 of 12715
# Running data on stemmbi01: record 807 of 12715
# Running data on tatepo01: record 808 of 12715
# Running data on thompsa01: record 809 of 12715
# Running data on visnejo01: record 810 of 12715
# Running data on wetzesh01: record 811 of 12715
# Running data on beglege01: record 812 of 12715
# Running data on bierblo01: record 813 of 12715
# Running data on blighne01: record 814 of 12715
# Running data on boyleja01: record 815 of 12715
# Running data on chambel01: record 816 of 12715
# Running data on clarkbo01: record 817 of 12715
# Running data on collihu01: record 818 of 12715
# Running data on connepe01: record 819 of 12715
# Running data on connore01: record 820 of 12715
# Running data on devliji02: record 821 of 12715
# Running data on donahji01: record 822 of 12715
# Running data on dugdada01: record 823 of 12715
# Running data on finlebi01: record 824 of 12715
# Running data on fosteel01: record 825 of 12715
# Running data on gallaji01: record 826 of 12715
# Running data on gilmofr01: record 827 of 12715
# Running data on handiji01: record 828 of 12715
# Running data on hardilo02: record 829 of 12715
# Running data on heinzja01: record 830 of 12715
# Running data on hellmto01: record 831 of 12715
# Running data on hudsona01: record 832 of 12715
# Running data on irwinbi01: record 833 of 12715
# Running data on joyce01: record 834 of 12715
# Running data on kilroma01: record 835 of 12715
# Running data on kinslto01: record 836 of 12715
# Running data on mackco01: record 837 of 12715
# Running data on marrle01: record 838 of 12715
# Running data on mcglojo01: record 839 of 12715
# Running data on meistjo01: record 840 of 12715
# Running data on moolige01: record 841 of 12715
# Running data on murphcl01: record 842 of 12715
# Running data on nealejo01: record 843 of 12715
# Running data on parsoch01: record 844 of 12715
# Running data on peloulo01: record 845 of 12715
# Running data on quinnto01: record 846 of 12715
# Running data on robinwi01: record 847 of 12715
# Running data on schomot01: record 848 of 12715
# Running data on schripo01: record 849 of 12715
# Running data on shindbi01: record 850 of 12715
# Running data on smithbi03: record 851 of 12715
# Running data on smithre01: record 852 of 12715
# Running data on sowdele01: record 853 of 12715
# Running data on strikjo01: record 854 of 12715
# Running data on terreto01: record 855 of 12715
# Running data on toolest01: record 856 of 12715
# Running data on vaughfa01: record 857 of 12715
# Running data on yingljo01: record 858 of 12715
# Running data on baldwma01: record 859 of 12715
# Running data on beeched01: record 860 of 12715
# Running data on brownwi01: record 861 of 12715
# Running data on careyro01: record 862 of 12715
# Running data on chapmfr01: record 863 of 12715
# Running data on collibi01: record 864 of 12715
# Running data on crossla01: record 865 of 12715
# Running data on cunnibe01: record 866 of 12715
# Running data on daniela01: record 867 of 12715
# Running data on fast01: record 868 of 12715
# Running data on flanaed01: record 869 of 12715
# Running data on flynned01: record 870 of 12715
# Running data on geissem01: record 871 of 12715
# Running data on gilksbo01: record 872 of 12715
# Running data on goodfmi01: record 873 of 12715
# Running data on griffmi01: record 874 of 12715
# Running data on hallch01: record 875 of 12715
# Running data on hempdu01: record 876 of 12715
# Running data on herred01: record 877 of 12715
# Running data on jackshe01: record 878 of 12715
# Running data on kappehe01: record 879 of 12715
# Running data on leitndo01: record 880 of 12715
# Running data on maddeki01: record 881 of 12715
# Running data on mckeaed01: record 882 of 12715
# Running data on morriha01: record 883 of 12715
# Running data on munyajo01: record 884 of 12715
# Running data on murphpa01: record 885 of 12715
# Running data on obriepe01: record 886 of 12715
# Running data on oconnja01: record 887 of 12715
# Running data on oneilfr01: record 888 of 12715
# Running data on orourto01: record 889 of 12715
# Running data on otterbi01: record 890 of 12715
# Running data on polhema01: record 891 of 12715
# Running data on rainejo01: record 892 of 12715
# Running data on ryancy01: record 893 of 12715
# Running data on sheami01: record 894 of 12715
# Running data on simonha01: record 895 of 12715
# Running data on sommepe01: record 896 of 12715
# Running data on spragch01: record 897 of 12715
# Running data on swababi01: record 898 of 12715
# Running data on tebeapa01: record 899 of 12715
# Running data on townsge01: record 900 of 12715
# Running data on toyji01: record 901 of 12715
# Running data on vanhage01: record 902 of 12715
# Running data on weyhigu01: record 903 of 12715
# Running data on wheelbo01: record 904 of 12715
# Running data on wrighbi01: record 905 of 12715
# Running data on banniji01: record 906 of 12715
# Running data on blairbi01: record 907 of 12715
# Running data on brynato01: record 908 of 12715
# Running data on buckldi01: record 909 of 12715
# Running data on burnehe01: record 910 of 12715
# Running data on burnsji01: record 911 of 12715
# Running data on campaco01: record 912 of 12715
# Running data on cantzba01: record 913 of 12715
# Running data on childcu01: record 914 of 12715
# Running data on delahed01: record 915 of 12715
# Running data on duffyhu01: record 916 of 12715
# Running data on ehretre01: record 917 of 12715
# Running data on farmebi01: record 918 of 12715
# Running data on farredu01: record 919 of 12715
# Running data on fullesh01: record 920 of 12715
# Running data on gibsowh01: record 921 of 12715
# Running data on greenjo01: record 922 of 12715
# Running data on gumbead01: record 923 of 12715
# Running data on hafnefr01: record 924 of 12715
# Running data on hamilbi01: record 925 of 12715
# Running data on higgibi01: record 926 of 12715
# Running data on hoovech01: record 927 of 12715
# Running data on hoydu01: record 928 of 12715
# Running data on keased01: record 929 of 12715
# Running data on klusmbi01: record 930 of 12715
# Running data on krockgu01: record 931 of 12715
# Running data on laroqsa01: record 932 of 12715
# Running data on long01: record 933 of 12715
# Running data on mcshape01: record 934 of 12715
# Running data on nichopa01: record 935 of 12715
# Running data on nichosa01: record 936 of 12715
# Running data on obrieda02: record 937 of 12715
# Running data on rayir01: record 938 of 12715
# Running data on sandebe01: record 939 of 12715
# Running data on schefte01: record 940 of 12715
# Running data on silched01: record 941 of 12715
# Running data on smithsk01: record 942 of 12715
# Running data on staleha01: record 943 of 12715
# Running data on sullimi01: record 944 of 12715
# Running data on sweenpe01: record 945 of 12715
# Running data on tomneph01: record 946 of 12715
# Running data on vanzadi01: record 947 of 12715
# Running data on wagenwo01: record 948 of 12715
# Running data on weavefa01: record 949 of 12715
# Running data on wellsja01: record 950 of 12715
# Running data on whitapa01: record 951 of 12715
# Running data on wilmowa01: record 952 of 12715
# Running data on wiseni01: record 953 of 12715
# Running data on yaikhe01: record 954 of 12715
# Running data on zinnfr01: record 955 of 12715
# Running data on anderva01: record 956 of 12715
# Running data on bausege01: record 957 of 12715
# Running data on beardol01: record 958 of 12715
# Running data on bellmja01: record 959 of 12715
# Running data on bittmre01: record 960 of 12715
# Running data on carlfr01: record 961 of 12715
# Running data on carnejo01: record 962 of 12715
# Running data on clarkha01: record 963 of 12715
# Running data on conovte01: record 964 of 12715
# Running data on crookja01: record 965 of 12715
# Running data on daybi01: record 966 of 12715
# Running data on dowiejo01: record 967 of 12715
# Running data on doyleja01: record 968 of 12715
# Running data on duffech01: record 969 of 12715
# Running data on duryeje01: record 970 of 12715
# Running data on earlebi01: record 971 of 12715
# Running data on ebrighi01: record 972 of 12715
# Running data on feeja01: record 973 of 12715
# Running data on fishech03: record 974 of 12715
# Running data on galliji01: record 975 of 12715
# Running data on gastrha01: record 976 of 12715
# Running data on gaulemi01: record 977 of 12715
# Running data on gillji01: record 978 of 12715
# Running data on grahaba01: record 979 of 12715
# Running data on hollawi01: record 980 of 12715
# Running data on hurleje01: record 981 of 12715
# Running data on johnssp01: record 982 of 12715
# Running data on krummal01: record 983 of 12715
# Running data on longhe01: record 984 of 12715
# Running data on mccafsp01: record 985 of 12715
# Running data on mccoyar01: record 986 of 12715
# Running data on mcmahsa01: record 987 of 12715
# Running data on meekda01: record 988 of 12715
# Running data on milledu01: record 989 of 12715
# Running data on pettych01: record 990 of 12715
# Running data on pickejo01: record 991 of 12715
# Running data on reillch02: record 992 of 12715
# Running data on reynoch02: record 993 of 12715
# Running data on riddljo01: record 994 of 12715
# Running data on rusieam01: record 995 of 12715
# Running data on ryanja01: record 996 of 12715
# Running data on scherha01: record 997 of 12715
# Running data on shannda01: record 998 of 12715
# Running data on stiveja01: record 999 of 12715
# Running data on swartpa01: record 1000 of 12715
# Running data on traffjo01: record 1001 of 12715
# Running data on weckbpe01: record 1002 of 12715
# Running data on adamsji01: record 1003 of 12715
# Running data on allenbo01: record 1004 of 12715
# ...
# Running data on wadats01: record 12388 of 12715
# Running data on walkech02: record 12389 of 12715
# Running data on westma03: record 12390 of 12715
# Running data on wheelze01: record 12391 of 12715
# Running data on wilkian01: record 12392 of 12715
# Running data on willija01: record 12393 of 12715
# Running data on ynoara01: record 12394 of 12715
# Running data on alberha01: record 12395 of 12715
# Running data on almonmi01: record 12396 of 12715
# Running data on alvarda02: record 12397 of 12715
# Running data on andrima01: record 12398 of 12715
# Running data on armstsh01: record 12399 of 12715
# Running data on asheral01: record 12400 of 12715
# Running data on ashlene01: record 12401 of 12715
# Running data on bandyje01: record 12402 of 12715
# Running data on barneau01: record 12403 of 12715
# Running data on baronst01: record 12404 of 12715
# Running data on barriyh01: record 12405 of 12715
# Running data on bellaan01: record 12406 of 12715
# Running data on birdgr01: record 12407 of 12715
# Running data on blairca01: record 12408 of 12715
# Running data on brachsi01: record 12409 of 12715
# Running data on brettry01: record 12410 of 12715
# Running data on britoso01: record 12411 of 12715
# Running data on browntr01: record 12412 of 12715
# Running data on broxtke01: record 12413 of 12715
# Running data on bryankr01: record 12414 of 12715
# Running data on burgoen02: record 12415 of 12715
# Running data on buxtoby01: record 12416 of 12715
# Running data on cabrera01: record 12417 of 12715
# Running data on calixor01: record 12418 of 12715
# Running data on canhama01: record 12419 of 12715
# Running data on castrda01: record 12420 of 12715
# Running data on cecilda01: record 12421 of 12715
# Running data on colemdu01: record 12422 of 12715
# Running data on confomi01: record 12423 of 12715
# Running data on cooneti01: record 12424 of 12715
# Running data on cornejo01: record 12425 of 12715
# Running data on correca01: record 12426 of 12715
# Running data on cowarka01: record 12427 of 12715
# Running data on cunnibr02: record 12428 of 12715
# Running data on cuthbch01: record 12429 of 12715
# Running data on deckeco01: record 12430 of 12715
# Running data on depaujo02: record 12431 of 12715
# Running data on deshide02: record 12432 of 12715
# Running data on diazel01: record 12433 of 12715
# Running data on dickeal01: record 12434 of 12715
# Running data on difowi01: record 12435 of 12715
# Running data on dornda01: record 12436 of 12715
# Running data on drurybr01: record 12437 of 12715
# Running data on duffyma02: record 12438 of 12715
# Running data on dykstal01: record 12439 of 12715
# Running data on easleed01: record 12440 of 12715
# Running data on eickhje01: record 12441 of 12715
# Running data on faulkan01: record 12442 of 12715
# Running data on feathta01: record 12443 of 12715
# Running data on ferreje01: record 12444 of 12715
# Running data on fieldda01: record 12445 of 12715
# Running data on florera02: record 12446 of 12715
# Running data on galero01: record 12447 of 12715
# Running data on gallojo01: record 12448 of 12715
# Running data on garciad01: record 12449 of 12715
# Running data on garnedu01: record 12450 of 12715
# Running data on givenmy01: record 12451 of 12715
# Running data on goforda01: record 12452 of 12715
# Running data on gonzase01: record 12453 of 12715
# Running data on gotttr01: record 12454 of 12715
# Running data on grahajr01: record 12455 of 12715
# Running data on guaipma01: record 12456 of 12715
# Running data on guerrju02: record 12457 of 12715
# Running data on hallco01: record 12458 of 12715
# Running data on hatlema01: record 12459 of 12715
# Running data on heathsl01: record 12460 of 12715
# Running data on hedgeau01: record 12461 of 12715
# Running data on hernaos01: record 12462 of 12715
# Running data on herreod01: record 12463 of 12715
# Running data on hicksjo02: record 12464 of 12715
# Running data on housead01: record 12465 of 12715
# Running data on iglesra01: record 12466 of 12715
# Running data on jackslu01: record 12467 of 12715
# Running data on jankotr01: record 12468 of 12715
# Running data on johnsmi04: record 12469 of 12715
# Running data on kangju01: record 12470 of 12715
# Running data on kellyry01: record 12471 of 12715
# Running data on keplema01: record 12472 of 12715
# Running data on kubitky01: record 12473 of 12715
# Running data on lamarry01: record 12474 of 12715
# Running data on lazora01: record 12475 of 12715
# Running data on leeza01: record 12476 of 12715
# Running data on liberad01: record 12477 of 12715
# Running data on lindofr01: record 12478 of 12715
# Running data on lolliry01: record 12479 of 12715
# Running data on lorenmi01: record 12480 of 12715
# Running data on machadi01: record 12481 of 12715
# Running data on mahtomi01: record 12482 of 12715
# Running data on mailelu01: record 12483 of 12715
# Running data on marksma01: record 12484 of 12715
# Running data on marrede01: record 12485 of 12715
# Running data on marteje01: record 12486 of 12715
# Running data on marteke01: record 12487 of 12715
# Running data on martira04: record 12488 of 12715
# Running data on mazzoco01: record 12489 of 12715
# Running data on mcgousc01: record 12490 of 12715
# Running data on meyeral01: record 12491 of 12715
# Running data on montgmi01: record 12492 of 12715
# Running data on morgaad01: record 12493 of 12715
# Running data on moscojo01: record 12494 of 12715
# Running data on muncyma01: record 12495 of 12715
# Running data on munoda01: record 12496 of 12715
# Running data on murphto04: record 12497 of 12715
# Running data on navarre01: record 12498 of 12715
# Running data on nicolju01: record 12499 of 12715
# Running data on noelri01: record 12500 of 12715
# Running data on obergsc01: record 12501 of 12715
# Running data on obriepe04: record 12502 of 12715
# Running data on olivehe01: record 12503 of 12715
# Running data on orlanpa01: record 12504 of 12715
# Running data on osichjo01: record 12505 of 12715
# Running data on owenshe02: record 12506 of 12715
# Running data on parkeja03: record 12507 of 12715
# Running data on penaar01: record 12508 of 12715
# Running data on perazjo01: record 12509 of 12715
# Running data on perezca02: record 12510 of 12715
# Running data on pindebr01: record 12511 of 12715
# Running data on piscost01: record 12512 of 12715
# Running data on plaweke01: record 12513 of 12715
# Running data on ravinjo01: record 12514 of 12715
# Running data on rearich01: record 12515 of 12715
# Running data on reedmi02: record 12516 of 12715
# Running data on refsnro01: record 12517 of 12715
# Running data on riverya01: record 12518 of 12715
# Running data on robleha01: record 12519 of 12715
# Running data on rodried05: record 12520 of 12715
# Running data on rosared01: record 12521 of 12715
# Running data on rumbeni01: record 12522 of 12715
# Running data on russead02: record 12523 of 12715
# Running data on saladty01: record 12524 of 12715
# Running data on sanchga02: record 12525 of 12715
# Running data on sanomi01: record 12526 of 12715
# Running data on schebsc01: record 12527 of 12715
# Running data on schwaky01: record 12528 of 12715
# Running data on seageco01: record 12529 of 12715
# Running data on severpe01: record 12530 of 12715
# Running data on shaffri01: record 12531 of 12715
# Running data on shawtr01: record 12532 of 12715
# Running data on solissa01: record 12533 of 12715
# Running data on stanlco01: record 12534 of 12715
# Running data on straury01: record 12535 of 12715
# Running data on sweenda02: record 12536 of 12715
# Running data on swihabl01: record 12537 of 12715
# Running data on tartatr01: record 12538 of 12715
# Running data on thomptr01: record 12539 of 12715
# Running data on tomasya01: record 12540 of 12715
# Running data on tomlike01: record 12541 of 12715
# Running data on torrero01: record 12542 of 12715
# Running data on travide01: record 12543 of 12715
# Running data on tuckepr01: record 12544 of 12715
# Running data on turnetr01: record 12545 of 12715
# Running data on urshegi01: record 12546 of 12715
# Running data on velasvi01: record 12547 of 12715
# Running data on verrelo01: record 12548 of 12715
# Running data on waldrky02: record 12549 of 12715
# Running data on willima07: record 12550 of 12715
# Running data on willima08: record 12551 of 12715
# Running data on winklda01: record 12552 of 12715
# Running data on wojcias01: record 12553 of 12715
# Running data on zychto01: record 12554 of 12715
# Running data on alcanra01: record 12555 of 12715
# Running data on alfarjo01: record 12556 of 12715
# Running data on almoral01: record 12557 of 12715
# Running data on anderti01: record 12558 of 12715
# Running data on antoldu01: record 12559 of 12715
# Running data on arciaor01: record 12560 of 12715
# Running data on asuajca01: record 12561 of 12715
# Running data on austity01: record 12562 of 12715
# Running data on barneda02: record 12563 of 12715
# Running data on barneto01: record 12564 of 12715
# Running data on baumabu01: record 12565 of 12715
# Running data on belljo02: record 12566 of 12715
# Running data on beninan01: record 12567 of 12715
# Running data on beresja01: record 12568 of 12715
# Running data on biagijo01: record 12569 of 12715
# Running data on blairaa01: record 12570 of 12715
# Running data on blashja01: record 12571 of 12715
# Running data on boscawi01: record 12572 of 12715
# Running data on bradlje01: record 12573 of 12715
# Running data on bregmal01: record 12574 of 12715
# Running data on bridwpa01: record 12575 of 12715
# Running data on burnsan01: record 12576 of 12715
# Running data on bushma01: record 12577 of 12715
# Running data on campojo01: record 12578 of 12715
# Running data on candeje01: record 12579 of 12715
# Running data on cardust01: record 12580 of 12715
# Running data on cecchga02: record 12581 of 12715
# Running data on cessalu01: record 12582 of 12715
# Running data on choiji01: record 12583 of 12715
# Running data on coatsja01: record 12584 of 12715
# Running data on concege01: record 12585 of 12715
# Running data on contrwi01: record 12586 of 12715
# Running data on cuevawi01: record 12587 of 12715
# Running data on dahlda01: record 12588 of 12715
# Running data on daytogr01: record 12589 of 12715
# Running data on delacjo01: record 12590 of 12715
# Running data on dermoma01: record 12591 of 12715
# Running data on diazal02: record 12592 of 12715
# Running data on diazed04: record 12593 of 12715
# Running data on doziehu01: record 12594 of 12715
# Running data on egeco01: record 12595 of 12715
# Running data on eibnebr01: record 12596 of 12715
# Running data on estevca01: record 12597 of 12715
# Running data on fraziad01: record 12598 of 12715
# Running data on freemmi01: record 12599 of 12715
# Running data on fulmemi01: record 12600 of 12715
# Running data on gamelbe01: record 12601 of 12715
# Running data on garnepe01: record 12602 of 12715
# Running data on giolilu01: record 12603 of 12715
# Running data on glasnty01: record 12604 of 12715
# Running data on goeddty01: record 12605 of 12715
# Running data on gonzaer01: record 12606 of 12715
# Running data on goodwbr01: record 12607 of 12715
# Running data on gourryu01: record 12608 of 12715
# Running data on grateju01: record 12609 of 12715
# Running data on gsellro01: record 12610 of 12715
# Running data on gustaja01: record 12611 of 12715
# Running data on hanigmi01: record 12612 of 12715
# Running data on hansoal01: record 12613 of 12715
# Running data on hathast01: record 12614 of 12715
# Running data on hazelje01: record 12615 of 12715
# Running data on healyry01: record 12616 of 12715
# Running data on heredgu01: record 12617 of 12715
# Running data on hernama02: record 12618 of 12715
# Running data on hernate01: record 12619 of 12715
# Running data on holdejo02: record 12620 of 12715
# Running data on hoodde01: record 12621 of 12715
# Running data on hoytja01: record 12622 of 12715
# Running data on jenkity01: record 12623 of 12715
# Running data on jenseky01: record 12624 of 12715
# Running data on jonesja07: record 12625 of 12715
# Running data on josepto01: record 12626 of 12715
# Running data on judgeaa01: record 12627 of 12715
# Running data on kellyca02: record 12628 of 12715
# Running data on kellyty01: record 12629 of 12715
# Running data on kempto01: record 12630 of 12715
# Running data on kiebosp01: record 12631 of 12715
# Running data on kimhy01: record 12632 of 12715
# Running data on kivlepa01: record 12633 of 12715
# Running data on kuhlch01: record 12634 of 12715
# Running data on leclejo01: record 12635 of 12715
# Running data on leeda02: record 12636 of 12715
# Running data on lopezre01: record 12637 of 12715
# Running data on maedake01: record 12638 of 12715
# Running data on mahlegr01: record 12639 of 12715
# Running data on mancitr01: record 12640 of 12715
# Running data on margoma01: record 12641 of 12715
# Running data on marteke02: record 12642 of 12715
# Running data on martijo08: record 12643 of 12715
# Running data on maxwebr01: record 12644 of 12715
# Running data on mazarno01: record 12645 of 12715
# Running data on mejiaad01: record 12646 of 12715
# Running data on mendeyo01: record 12647 of 12715
# Running data on merriry01: record 12648 of 12715
# Running data on merriwh01: record 12649 of 12715
# Running data on millemi01: record 12650 of 12715
# Running data on minayju01: record 12651 of 12715
# Running data on molledu01: record 12652 of 12715
# Running data on moncayo01: record 12653 of 12715
# Running data on mondera02: record 12654 of 12715
# Running data on moranco01: record 12655 of 12715
# Running data on morofma01: record 12656 of 12715
# Running data on motteta01: record 12657 of 12715
# Running data on musgrjo01: record 12658 of 12715
# Running data on naquity01: record 12659 of 12715
# Running data on narvaom01: record 12660 of 12715
# Running data on nichobr01: record 12661 of 12715
# Running data on nimmobr01: record 12662 of 12715
# Running data on nunezre01: record 12663 of 12715
# Running data on okertst01: record 12664 of 12715
# Running data on olsonma02: record 12665 of 12715
# Running data on parkby01: record 12666 of 12715
# Running data on pattejo03: record 12667 of 12715
# Running data on penafe01: record 12668 of 12715
# Running data on perdolu02: record 12669 of 12715
# Running data on perezye01: record 12670 of 12715
# Running data on pindech01: record 12671 of 12715
# Running data on poundbr01: record 12672 of 12715
# Running data on quereju01: record 12673 of 12715
# Running data on quinnro01: record 12674 of 12715
# Running data on reedaj01: record 12675 of 12715
# Running data on rendato01: record 12676 of 12715
# Running data on renfrhu01: record 12677 of 12715
# Running data on reynoma03: record 12678 of 12715
# Running data on rickajo01: record 12679 of 12715
# Running data on rivertj01: record 12680 of 12715
# Running data on rodrijo04: record 12681 of 12715
# Running data on rondojo02: record 12682 of 12715
# Running data on rosaral01: record 12683 of 12715
# Running data on ruizri01: record 12684 of 12715
# Running data on saupowa01: record 12685 of 12715
# Running data on schimry01: record 12686 of 12715
# Running data on scottro02: record 12687 of 12715
# Running data on segedro01: record 12688 of 12715
# Running data on selskst01: record 12689 of 12715
# Running data on smithbl01: record 12690 of 12715
# Running data on smithke04: record 12691 of 12715
# Running data on smithma05: record 12692 of 12715
# Running data on snellbl01: record 12693 of 12715
# Running data on stallja01: record 12694 of 12715
# Running data on stewabr01: record 12695 of 12715
# Running data on storytr01: record 12696 of 12715
# Running data on stratch01: record 12697 of 12715
# Running data on stumpda01: record 12698 of 12715
# Running data on suareal01: record 12699 of 12715
# Running data on swansda01: record 12700 of 12715
# Running data on tapiara01: record 12701 of 12715
# Running data on tilsoch01: record 12702 of 12715
# Running data on tolesan01: record 12703 of 12715
# Running data on torrejo02: record 12704 of 12715
# Running data on uriasju01: record 12705 of 12715
# Running data on valaipa01: record 12706 of 12715
# Running data on vogelda01: record 12707 of 12715
# Running data on walshco02: record 12708 of 12715
# Running data on wendejb01: record 12709 of 12715
# Running data on wendljo01: record 12710 of 12715
# Running data on whitety01: record 12711 of 12715
# Running data on wimmeal01: record 12712 of 12715
# Running data on wolteto01: record 12713 of 12715
# Running data on ynoaga01: record 12714 of 12715

# %%
print(batting_df.shape)
batting_df.head()
# Out:
# (12715, 20)
#        2B      3B        BA      BB    HBP HOF     HR   IBB       OBP  \
# 0    0.01    0.01  0.002500    0.01   0.01   N   0.01  0.01  0.007444
# 1   35.00   12.02  0.277011   19.01   0.07   N   1.06  0.07  0.288029
# 2   19.00    8.02  0.254054    5.03   0.06   N   1.05  0.06  0.259129
# 3  581.00  142.00  0.332587  983.00  32.16   N  97.10  0.27  0.392578
# 4    2.00    1.00  0.224490    0.01   0.01   N   0.01  0.01  0.224760
#
#         OPS      SB    SF       SLG           firstName   games     hits  \
# 0  0.024944    0.01  0.01  0.017500   Francis Patterson     1.0     0.01
# 1  0.615584   30.03  0.07  0.327555       Robert Edward   274.0   341.00
# 2  0.564791   10.03  0.06  0.305662     Arthur Algernon   168.0   188.00
# 3  0.837679  276.11  0.27  0.445101  Adrian Constantine  2523.0  3418.00
# 4  0.531495    0.01  0.01  0.306735              Robert    12.0    11.00
#
#       lastName  player_id     runs  seasons
# 0  Abercrombie  abercda01     0.01      1.0
# 1         Addy   addybo01   227.00      7.0
# 2      Allison  allisar01   106.00      6.0
# 3        Anson  ansonca01  1996.00     27.0
# 4    Armstrong  armstbo01     9.00      1.0

# %%
# JOIN WAR VALUE BASED ON PLAYER_ID
wars = "Resources/war.csv"
w_df = pd.read_csv(wars)
batting_data=pd.merge(batting_df, w_df, how='left',on='player_id')
batting_data['WAR'].fillna(0, inplace=True)
batting_data.head()
# Out:
#        2B      3B        BA      BB    HBP HOF     HR   IBB       OBP  \
# 0    0.01    0.01  0.002500    0.01   0.01   N   0.01  0.01  0.007444
# 1   35.00   12.02  0.277011   19.01   0.07   N   1.06  0.07  0.288029
# 2   19.00    8.02  0.254054    5.03   0.06   N   1.05  0.06  0.259129
# 3  581.00  142.00  0.332587  983.00  32.16   N  97.10  0.27  0.392578
# 4    2.00    1.00  0.224490    0.01   0.01   N   0.01  0.01  0.224760
#
#         OPS  ...      SF       SLG           firstName   games     hits  \
# 0  0.024944  ...    0.01  0.017500   Francis Patterson     1.0     0.01
# 1  0.615584  ...    0.07  0.327555       Robert Edward   274.0   341.00
# 2  0.564791  ...    0.06  0.305662     Arthur Algernon   168.0   188.00
# 3  0.837679  ...    0.27  0.445101  Adrian Constantine  2523.0  3418.00
# 4  0.531495  ...    0.01  0.306735              Robert    12.0    11.00
#
#       lastName  player_id     runs  seasons    WAR
# 0  Abercrombie  abercda01     0.01      1.0  -0.07
# 1         Addy   addybo01   227.00      7.0   2.89
# 2      Allison  allisar01   106.00      6.0   0.20
# 3        Anson  ansonca01  1996.00     27.0  93.92
# 4    Armstrong  armstbo01     9.00      1.0   0.00
#
# [5 rows x 21 columns]

# %%
# CONVERT FINAL BATTING DF TO CSV
# HOF COLUMN DENOTES WHETHER NOMINATED(OR INDUCTED) IN THE HALL OF FAME WITH A 'Y' OR 'N'
batting_data.to_csv('Resources/batting_data.csv')
