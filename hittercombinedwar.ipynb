# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
batters = "battersW10YRS.csv"
wars = "war.csv"

# %%
b_df = pd.read_csv(batters)
w_df = pd.read_csv(wars)

# %%
combined_data=pd.merge(b_df, w_df, how='left',on='player_id')

combined_data.head()
# Out:
#    Unnamed: 0      2B      3B        BA      BB    HBP HOF     HR   IBB  \
# 0           0  581.00  142.00  0.332587  983.00  32.16   N  97.10  0.27
# 1           1   74.00   17.04  0.254141   65.00   0.10   N   8.06  0.10
# 2           2   85.01   31.05  0.274156   48.00   0.12   N   0.12  0.12
# 3           3   70.02   30.02  0.260660   42.02   0.10   N   8.08  0.12
# 4           4   56.02   13.04  0.275695   26.02   0.12   N   0.12  0.12
#
#         OBP  ...      SF       SLG  extra_base_hits           firstName  \
# 0  0.392578  ...    0.27  0.445101              0.0  Adrian Constantine
# 1  0.276421  ...    0.10  0.316735              0.0        Edgar Edward
# 2  0.287606  ...    0.12  0.332078              0.0        David Daniel
# 3  0.273193  ...    0.12  0.323898              0.0        Charles John
# 4  0.283233  ...    0.12  0.308932              0.0       Michael Henry
#
#     games     hits  lastName  player_id     runs    WAR
# ...

# %%
combined_data.to_csv('hitterdata.csv')
